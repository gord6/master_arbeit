# %%
import pandas as pd

import numpy as np

import re

# %%
config_algo_names = ['CommonChars', 'ContainsSubstring', 'CountVowels','ReverseArray', 'BinarySearchStrings', 'Multiples','CrossSum', 'Swap',  'InsertionSort','GreatestCommonDivisor']

config_unique_code_variable = "PD14_01"

config_answer_variables = ['PT03_01', 'PT08_01', 'PT13_01', 'PT18_01', 'PT23_01','PT28_01', 'PT33_01', 'PT38_01', 'PT43_01', 'PT48_01']

config_difficulty_variables = ['PT04', 'PT09', 'PT14', 'PT19', 'PT24', 'PT30', 'PT34', 'PT39', 'PT44', 'PT49']

config_time_variables = ['TIME006','TIME008','TIME010','TIME012', 'TIME014','TIME016','TIME018','TIME020','TIME022', 'TIME024']

config_click_variables = ['PT01_01', 'PT06_01', 'PT11_01', 'PT16_01', 'PT21_01','PT26_01', 'PT31_01', 'PT36_01', 'PT41_01', 'PT46_01']

config_correctness_variables = ['^1$', '^(?i)true$', '^4$', '^210461$', '^1$', 
                                '^32$', '^8$', '^42$', '^12578$', '^4$']



config_datasheet = r'./pretest.xlsx'
# Out:
# False

# %%
raw = pd.read_excel(config_datasheet)
df = pd.DataFrame(raw)
df = df.dropna()

from scipy.stats import ttest_ind

# %%
df_matrix = []
raw = pd.read_excel(config_datasheet)

# load data
for row, _stuff in enumerate(config_algo_names):
    df_array = []
    df = pd.DataFrame(raw, columns = [config_unique_code_variable,
                                      config_answer_variables[row],
                                      config_correctness_variables[row],
                                      config_difficulty_variables[row],
                                      config_time_variables[row],
                                      config_click_variables[row],])
    #df = df.dropna()
    df_array.append(df)
    df_matrix.append(df_array)

# %%
cols = ["unique_code", "response_time", "correctness", "difficulty", "flag", "algo_name", "click_data"]

df_tmp = pd.DataFrame(columns=cols)

for row_idx, df_row in enumerate(df_matrix):
    algo_name = config_algo_names[row_idx]
    for col, df in enumerate(df_row): 
        
        for index, row in df.iterrows():
            unique_code = row["PD14_01"]
            response_time = int(row[config_time_variables[row_idx]])
            
            if row_idx == 3:
                answer = str(row[config_answer_variables[row_idx]])
                rep = {"{": "", "+": "", " ":"", ",":"", "[":"", "]":"", "}":""} # define desired replacements here

                rep = dict((re.escape(k), v) for k, v in rep.items()) 
                pattern = re.compile("|".join(rep.keys()))
                answer = pattern.sub(lambda m: rep[re.escape(m.group(0))], answer)
            elif row_idx == 8:
                answer = str(row[config_answer_variables[row_idx]])
                rep = {"{": "", "+": "", " ":"", ",":"", "[":"", "]":"", "}":""} # define desired replacements here
                rep = dict((re.escape(k), v) for k, v in rep.items()) 
                pattern = re.compile("|".join(rep.keys()))
                answer = pattern.sub(lambda m: rep[re.escape(m.group(0))], answer)
            else:
                answer = row[config_answer_variables[row_idx]]
            
            difficulty = row[config_difficulty_variables[row_idx]]
            click_data = row[config_click_variables[row_idx]]
            flag = ""
            
            correctness = bool(re.match(config_correctness_variables[row_idx], str(answer)))
            data = pd.DataFrame([[unique_code, response_time, correctness, difficulty, flag, algo_name, click_data]], columns=cols)
                  
            df_tmp = df_tmp.append(data)
#7nKTra Swap manuell richtig
#5iOPrl GGT manuell richtig
# Out:
# 0 False a
# 0 True 1
# 0 True 1
# 0 True 1
# 0 True 1
# 0 True 1
# 0 False Hamburg
# 0 True 1
# 0 False 4
# 0 True 1
# 0 True 1
# 0 True 1
# 0 True 1
# 0 True 1
# 0 True 1
# 0 False 9, 7
# 0 True 1
# 0 True 1
# 0 False 5
# 0 False 7
# 0 True 1
# 0 False 5
# 0 True 1
# 0 True 1
# 0 True 1
# 0 True 1
# 0 True 1
# 0 True 1
# 0 True 1
# 0 True 1
# 0 False Magdeburg
# 0 True 1
# 0 True 1
# 0 True 1
# 0 True 1
# 0 False 0
# 0 True 1
# 0 True 1
# 0 True 1
# 0 False 7
# 0 False 7
# 0 True 1
# 0 True 1
# 0 False 0
# 0 True 1
# 0 True 1
# 0 True 1
# 0 False 6
# 0 True 1
# 0 False 6
# 0 True 1
# 0 False 2
# 1 True true
# 1 True true
# 1 False false
# 1 True true
# 1 True true
# 1 True true
# 1 False Zeug
# 1 True true
# 1 True true
# 1 True true
# 1 True true
# 1 True true
# 1 True true
# 1 True true
# 1 False 0
# 1 False Spielzeugauto, 3
# 1 True True
# 1 False false
# 1 True true
# 1 True true
# 1 True true
# 1 True true
# 1 True true
# 1 False false
# 1 True true
# 1 False false
# 1 True true
# 1 True true
# 1 True true
# 1 True true
# 1 False zeug
# 1 True true
# 1 True true
# 1 True true
# 1 True true
# 1 True true
# 1 True true
# 1 True true
# 1 True true
# 1 True true
# 1 True true
# 1 True true
# 1 True true
# 1 True True
# 1 True True
# 1 True true
# 1 True true
# 1 True true
# 1 False false
# 1 True true
# 1 False false
# 1 True true
# 2 True 4
# 2 True 4
# 2 True 4
# 2 True 4
# 2 True 4
# 2 True 4
# 2 False 1
# 2 True 4
# 2 True 4
# 2 True 4
# 2 True 4
# 2 True 4
# 2 True 4
# 2 True 4
# 2 True 4
# 2 True 4
# 2 True 4
# 2 True 4
# 2 True 4
# 2 False 3
# 2 True 4
# 2 False 4, aber Syntaxfehler in erster for-Schleife word.length() müsste word.length sein?
# 2 True 4
# 2 True 4
# 2 True 4
# 2 True 4
# 2 True 4
# 2 True 4
# 2 True 4
# 2 True 4
# 2 True 4
# 2 True 4
# 2 True 4
# 2 True 4
# 2 True 4
# 2 True 4
# 2 True 4
# 2 True 4
# 2 True 4
# 2 True 4
# 2 True 4
# 2 True 4
# 2 True 4
# 2 True 4
# 2 True 4
# 2 True 4
# 2 False 3
# 2 True 4
# 2 True 4
# 2 True 4
# 2 True 4
# 2 True 4
# 3 True 210461
# 3 True 210461
# 3 True 210461
# 3 True 210461
# 3 False 164102
# 3 True 210461
# 3 False 4
# 3 True 210461
# 3 True 210461
# 3 True 210461
# 3 True 210461
# 3 True 210461
# 3 True 210461
# 3 True 210461
# 3 True 210461
# 3 False 5
# 3 True 210461
# 3 True 210461
# 3 True 210461
# 3 False 10461
# 3 True 210461
# 3 True 210461
# 3 True 210461
# 3 True 210461
# 3 True 210461
# 3 False 2
# 3 True 210461
# 3 False 410216
# 3 True 210461
# 3 True 210461
# 3 True 210461
# 3 True 210461
# 3 True 210461
# 3 True 210461
# 3 True 210461
# 3 True 210461
# 3 False 164102
# 3 False 210561
# 3 False 164102
# 3 True 210461
# 3 True 210461
# 3 True 210461
# 3 True 210461
# 3 True 210461
# 3 True 210461
# 3 True 210461
# 3 True 210461
# 3 True 210461
# 3 True 210461
# 3 True 210461
# 3 False 21046
# 3 False 106421
# 4 True 1
# 4 True 1
# 4 False -1
# 4 True 1
# 4 True 1
# 4 True 1
# 4 False -1
# 4 False 2
# 4 True 1
# 4 True 1
# 4 False 2
# 4 True 1
# 4 True 1
# 4 True 1
# 4 True 1
# 4 False gesuchtes Wort aus dem Array
# 4 True 1
# 4 True 1
# 4 False -1
# 4 False -1
# 4 True 1
# 4 False 1 (richtige Ergebnis wird allerdings nur zufällig gefunden? -> nach was ist das String-Array sortiert?)
# 4 True 1
# 4 False 2
# 4 True 1
# 4 False 2
# 4 True 1
# 4 False 2
# 4 True 1
# 4 True 1
# 4 False 2
# 4 False 5
# 4 True 1
# 4 True 1
# 4 True 1
# 4 True 1
# 4 True 1
# 4 False -1
# 4 False 2
# 4 False 3
# 4 False 3
# 4 False 2
# 4 False 0
# 4 True 1
# 4 True 1
# 4 True 1
# 4 True 1
# 4 True 1
# 4 True 1
# 4 False tu, java, software, programmieren
# 4 False 2
# 4 False 16
# 5 False 7
# 5 False 13
# 5 False 6
# 5 True 32
# 5 True 32
# 5 False 7
# 5 False 5
# 5 True 32
# 5 False 13
# 5 False 1
# 5 False 7
# 5 False 7
# 5 True 32
# 5 False 23
# 5 False 6
# 5 False keine Ahnung
# 5 True 32
# 5 True 32
# 5 True 32
# 5 False 34
# 5 False 7
# 5 True 32
# 5 False 6
# 5 False 5
# 5 False 7
# 5 False 5
# 5 False 6
# 5 False 6
# 5 False 13
# 5 True 32
# 5 False 40
# 5 True 32
# 5 True 32
# 5 False 28
# 5 True 32
# 5 True 32
# 5 False 23
# 5 False 29
# 5 True 32
# 5 False 6
# 5 False 6
# 5 False 7
# 5 True 32
# 5 True 32
# 5 False 38
# 5 False 65
# 5 False 6
# 5 False 26
# 5 True 32
# 5 False 5
# 5 False 45
# 5 False 7
# 6 True 8
# 6 True 8
# 6 True 8
# 6 True 8
# 6 True 8
# 6 True 8
# 6 False 35.53
# 6 True 8
# 6 True 8
# 6 True 8
# 6 True 8
# 6 True 8
# 6 True 8
# 6 True 8
# 6 True 8
# 6 False Kreuzsumme von 323
# 6 True 8
# 6 True 8
# 6 True 8
# 6 False 7
# 6 True 8
# 6 True 8
# 6 True 8
# 6 False 6
# 6 True 8
# 6 True 8
# 6 True 8
# 6 True 8
# 6 True 8
# 6 True 8
# 6 False 36
# 6 True 8
# 6 True 8
# 6 True 8
# 6 True 8
# 6 True 8
# 6 True 8
# 6 True 8
# 6 True 8
# 6 True 8
# 6 True 8
# 6 True 8
# 6 False 9
# 6 True 8
# 6 False 11
# 6 False 1988-08-01 00:00:00
# 6 True 8
# 6 True 8
# 6 True 8
# 6 True 8
# 6 True 8
# 6 False 323
# 7 False 42 23
# 7 True 42
# 7 True 42
# 7 True 42
# 7 True 42
# 7 True 42
# 7 True 42
# 7 True 42
# 7 False 23
# 7 True 42
# 7 True 42
# 7 True 42
# 7 True 42
# 7 True 42
# 7 True 42
# 7 False Positionstausch von Var 1 mit Var 2 im Array
# 7 True 42
# 7 False 42 23
# 7 True 42
# 7 True 42
# 7 True 42
# 7 False 23
# 7 True 42
# 7 True 42
# 7 True 42
# 7 True 42
# 7 True 42
# 7 True 42
# 7 True 42
# 7 True 42
# 7 False 42.23
# 7 True 42
# 7 True 42
# 7 True 42
# 7 True 42
# 7 True 42
# 7 True 42
# 7 True 42
# 7 True 42
# 7 True 42
# 7 True 42
# 7 True 42
# 7 True 42
# 7 False 42, 23
# 7 True 42
# 7 True 42
# 7 True 42
# 7 True 42
# 7 True 42
# 7 True 42
# 7 True 42
# 7 True 42
# 8 True 12578
# 8 True 12578
# 8 True 12578
# 8 True 12578
# 8 True 12578
# 8 True 12578
# 8 False 518
# 8 False 87521
# 8 True 12578
# 8 True 12578
# 8 True 12578
# 8 True 12578
# 8 True 12578
# 8 True 12578
# 8 True 12578
# 8 False dieLängedesArrays:5
# 8 False 51278
# 8 True 12578
# 8 True 12578
# 8 False 18527
# 8 True 12578
# 8 True 12578
# 8 True 12578
# 8 True 12578
# 8 True 12578
# 8 False 51827
# 8 True 12578
# 8 True 12578
# 8 True 12578
# 8 True 12578
# 8 True 12578
# 8 True 12578
# 8 True 12578
# 8 True 12578
# 8 True 12578
# 8 True 12578
# 8 True 12578
# 8 True 12578
# 8 True 12578
# 8 True 12578
# 8 True 12578
# 8 True 12578
# 8 True 12578
# 8 True 12578
# 8 False 87521
# 8 False 87521
# 8 True 12578
# 8 True 12578
# 8 True 12578
# 8 True 12578
# 8 True 12578
# 8 True 12578
# 9 True 4
# 9 True 4
# 9 False 8
# 9 True 4
# 9 True 4
# 9 True 4
# 9 False 8%12
# 9 False 5
# 9 False 8
# 9 True 4
# 9 True 4
# 9 True 4
# 9 True 4
# 9 False 2
# 9 True 4
# 9 False Größter gemeinsamer Teiler von 8 und 12 -> 4
# 9 True 4
# 9 True 4
# 9 True 4
# 9 True 4
# 9 True 4
# 9 True 4
# 9 True 4
# 9 True 4
# 9 True 4
# 9 True 4
# 9 True 4
# 9 True 4
# 9 True 4
# 9 True 4
# 9 True 4
# 9 True 4
# 9 True 4
# 9 True 4
# 9 True 4
# 9 True 4
# 9 True 4
# 9 True 4
# 9 True 4
# 9 True 4
# 9 True 4
# 9 False 12
# 9 True 4
# 9 False 8
# 9 True 4
# 9 True 4
# 9 True 4
# 9 True 4
# 9 True 4
# 9 True 4
# 9 True 4
# 9 False 12

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
cols = ["Unique Code", "ResponseTime", "Algorithm", "Flag", "Correctness", "Difficulty", "ClickData"]

def fill(list_data, dataframe):
    for idx, row in dataframe.iterrows():
        response_time = row["response_time"]
        algorithm = row["algo_name"]
        flag = row["flag"]
        click_data = row["click_data"]
        correctness = row["correctness"]
        difficulty = row["difficulty"]
        unique_code = row["unique_code"]
        list_data.append([unique_code, response_time, algorithm, flag, correctness, difficulty, click_data])

data = []
fill(data, df_tmp)
df = pd.DataFrame(data, columns=cols)
df.to_excel("./results/preprocessed.xlsx", index=False)

# %%
# Out:
#     Unique Code  ResponseTime              Algorithm Flag Correctness  \
# 0       1nUSüa            162            CommonChars
# 1        2rRLeh           167            CommonChars
# 2        6aRJhu           133            CommonChars
# 3        4iTGho           120            CommonChars
# 4        2nGAhe           132            CommonChars
# ..          ...           ...                    ...  ...         ...
# 515      5uHJei           114  GreatestCommonDivisor
# 516      5nFKho           157  GreatestCommonDivisor
# 517      4yMAta           542  GreatestCommonDivisor
# 518      4iMVha            80  GreatestCommonDivisor
# 519      2aRCei            28  GreatestCommonDivisor
#
#      Difficulty                                          ClickData
# 0             2  182-163 182-207 122-95 102-17 110-55 147-34 14...
# 1             1  220-195 199-160 103-49 82-12 120-63 151-37 161...
# 2             1  196-96 98-11 126-35 144-59 150-98 154-144 164-...
# 3             2  150-295 119-140 354-153 172-182 115-221 110-25...
# 4             1  111-2 141-50 204-60 186-59 202-46 168-71 154-1...
# ..          ...                                                ...
# 515           2  184-44 144-64 140-82 147-110 413-96 95-77 122-...
# 516           1  171-112 152-74 150-60 156-40 144-48 140-58 147...
# 517           2  184-82 90-9 108-14 103-56 139-56 136-30 123-59...
# 518           1  189-117 160-62 133-46 156-73 162-102 306-96 14...
# 519           2  163-44 131-64 134-101 151-139 157-160 104-155 ...
#
# [520 rows x 7 columns]
