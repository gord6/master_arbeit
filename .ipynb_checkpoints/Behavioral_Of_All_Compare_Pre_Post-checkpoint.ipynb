# %% [markdown]
# imports

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# %% [markdown]
# config

# %%
config_datasheet_pre = r'./results/preprocessed/preprocessed_pretest.xlsx'
config_datasheet_post = r'./results/preprocessed/preprocessed_posttest.xlsx'

# %% [markdown]
# import df

# %%
raw_pre = pd.read_excel(config_datasheet_pre)
raw_post = pd.read_excel(config_datasheet_post)
df_pre = pd.DataFrame(raw_pre)
df_post = pd.DataFrame(raw_post)

codes_pre = df_pre["Unique Code"].unique()
codes_post = df_post["Unique Code"].unique()

common_names = ["CommonChars", "ReverseArray", "BinarySearchStrings", "Multiples", "InsertionSort"]

for name in common_names:
    df_pre.replace(name, name+"-Pre", inplace=True)
    df_post.replace(name, name+"-Post", inplace=True)


df_result = pd.DataFrame()

codes_result_set = set(codes_pre) & set(codes_post)
codes_result = list(codes_result_set)

codes_result.sort()
codes_result.remove('5dHSfo')

counter = 0

for code in codes_result:
    tmp_pre = df_pre.loc[df_pre["Unique Code"]== code]
    tmp_post = df_post.loc[df_post["Unique Code"]==code]
    df_result = df_result.append(tmp_pre)
    df_result = df_result.append(tmp_post)

df_result.to_excel("results/behavioral/compare/compare.xlsx")

# %% [markdown]
# remove outliers

# %% [markdown]
# create result

# %%
bar_df = pd.DataFrame([],columns=["Correctness-Pre", "Correctness-Post", "Algorithm"])

mean_pre_total = 0
mean_post_total = 0



algo_names_pre = ["ContainsSubstring", "CountVowels", "CrossSum", "Swap", "GreatestCommonDivisor"]
algo_names_post = ["IsPalindrome", "ReverseString", "Power", "GetMiddle", "SquareRoot"]


#for i in range(len(algo_names_pre)):
#    mean_pre = float(df_result.loc[df_result["Algorithm"] == algo_names_pre[i]]["Correctness"].mean()*100)
#    mean_post = float(df_result.loc[df_result["Algorithm"] == algo_names_post[i]]["Correctness"].mean()*100)
#    mean_pre_total += mean_pre
#    mean_post_total += mean_post
#


for i in range(len(common_names)):
    mean_pre = float(df_result.loc[df_result["Algorithm"] == common_names[i]+"-Pre"]["Correctness"].mean()*100)
    mean_post = float(df_result.loc[df_result["Algorithm"] == common_names[i]+"-Post"]["Correctness"].mean()*100)
    mean_pre_total += mean_pre
    mean_post_total += mean_post
    
    
    bar_df = bar_df.append(pd.DataFrame([[mean_pre, mean_post, "V" + str(i+1)]], columns=["Correctness-Pre", "Correctness-Post", "Algorithm"]))

mean_pre_total /= (len(common_names))
mean_post_total /= (len(common_names))

bar_df = bar_df.append(pd.DataFrame([[mean_pre_total, mean_post_total, "Insgesamt"]], columns=["Correctness-Pre", "Correctness-Post", "Algorithm"]))
bar_df = bar_df.rename(columns={'Algorithm':'Programmverständnisaufgaben','Correctness-Pre': 'Korrektheit Pretest', 'Correctness-Post': 'Korrektheit Posttest'})
display(bar_df)


bar_df = bar_df.set_index('Programmverständnisaufgaben')
ax = bar_df.plot.bar(ylabel='Prozent', rot=0)
plt.tight_layout()
ax.legend(loc="center left", bbox_to_anchor=(1.0, 0.5))
plt.savefig("results/behavioral/v_korrektheit.pdf", bbox_inches='tight', pad_inches=0.01)
# Out:
#    Korrektheit Pretest  Korrektheit Posttest Programmverständnisaufgaben
# 0            85.714286             85.714286                          V1
# 0            80.952381             90.476190                          V2
# 0            75.000000             70.000000                          V3
# 0            52.380952             42.857143                          V4
# 0            90.476190            100.000000                          V5
# 0            76.904762             77.809524                   Insgesamt

# %%
bar_df = pd.DataFrame([],columns=["ResponseTime-Pre", "ResponseTime-Post", "Algorithm"])

mean_pre_total = 0
mean_post_total = 0

algo_names_pre = ["ContainsSubstring", "CountVowels", "CrossSum", "Swap", "GreatestCommonDivisor"]
algo_names_post = ["IsPalindrome", "ReverseString", "Power", "GetMiddle", "SquareRoot"]


#for i in range(len(algo_names_pre)):
#    mean_pre = float(df_result.loc[df_result["Algorithm"] == algo_names_pre[i]]["ResponseTime"].mean())
#    mean_post = float(df_result.loc[df_result["Algorithm"] == algo_names_post[i]]["ResponseTime"].mean())
#    mean_pre_total += mean_pre
#    mean_post_total += mean_post
#

pre_list = []
post_list = []


for i in range(len(common_names)):
    print(df_result.loc[df_result["Algorithm"]==common_names[i]+"-Pre"]["ResponseTime"].std())
    print(df_result.loc[df_result["Algorithm"]==common_names[i]+"-Post"]["ResponseTime"].std())
    pre_list.append(df_result.loc[df_result["Algorithm"]==common_names[i]+"-Pre"]["ResponseTime"].tolist())
    post_list.append(df_result.loc[df_result["Algorithm"]==common_names[i]+"-Post"]["ResponseTime"].tolist())

    mean_pre = float(df_result.loc[df_result["Algorithm"] == common_names[i]+"-Pre"]["ResponseTime"].mean())
    mean_post = float(df_result.loc[df_result["Algorithm"] == common_names[i]+"-Post"]["ResponseTime"].mean())
    mean_pre_total += mean_pre
    mean_post_total += mean_post
    
    
    bar_df = bar_df.append(pd.DataFrame([[mean_pre, mean_post, "V" + str(i+1)]], 
                                        columns=["ResponseTime-Pre", "ResponseTime-Post", "Algorithm"]))
    
    

pre_flat_list = [item for sublist in pre_list for item in sublist]
post_flat_list = [item for sublist in post_list for item in sublist]

import statistics
print("STD", statistics.stdev(pre_flat_list))
print("STD-Post", statistics.stdev(post_flat_list))

mean_pre_total /= (len(common_names))
mean_post_total /= (len(common_names))

bar_df = bar_df.append(pd.DataFrame([[mean_pre_total, mean_post_total, "Insgesamt"]], 
                                    columns=["ResponseTime-Pre", "ResponseTime-Post", "Algorithm"]))
bar_df = bar_df.rename(columns={'Algorithm':'Programmverständnisaufgaben','ResponseTime-Pre': 'Beantwortungszeit Pretest',
                                'ResponseTime-Post': 'Beantwortungszeit Posttest'})
display(bar_df)
def Average(lst):
    return sum(lst) / len(lst)

print(Average(pre_flat_list))
print(Average(post_flat_list))

bar_df = bar_df.set_index('Programmverständnisaufgaben')
ax = bar_df.plot.bar(ylabel='Sekunden', rot=0)
plt.tight_layout()
#plt.figure(figsize=(20.5, 10.5))
ax.legend(loc="center left", bbox_to_anchor=(1.0, 0.5))
plt.savefig("results/behavioral/v_beantwortungszeit.pdf", bbox_inches='tight', pad_inches=0.01, dpi=300)
# Out:
# 38.562071175357445
# 29.339231008846774
# 65.2882983754509
# 33.47031378343957
# 136.20320538773944
# 57.44954307912291
# 44.01055068308702
# 46.83054558725533
# 115.92820027520317
# 69.90108657783443
# STD 90.53052033443693
# STD-Post 50.735310142887634
#    Beantwortungszeit Pretest  Beantwortungszeit Posttest  \
# 0                 121.333333                   73.761905
# 0                 121.190476                   72.476190
# 0                 187.050000                   86.350000
# 0                 125.857143                  112.000000
# 0                 119.047619                   87.523810
# 0                 134.895714                   86.422381
#
#   Programmverständnisaufgaben
# 0                          V1
# 0                          V2
# 0                          V3
# 0                          V4
# 0                          V5
# 0                   Insgesamt
# 134.39423076923077
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-7b8261c12175> in <module>
#      55
#      56 print(Average(pre_flat_list))
# ---> 57 pritn(Average(post_flat_list))
#      58
#      59 bar_df = bar_df.set_index('Programmverständnisaufgaben')
#
# NameError: name 'pritn' is not defined

# %%
bar_df = pd.DataFrame([],columns=["Correctness-Pre", "Correctness-Post", "Algorithm"])

mean_pre_total = 0
mean_post_total = 0

algo_names_pre = ["ContainsSubstring", "CountVowels", "CrossSum", "Swap", "GreatestCommonDivisor"]
algo_names_post = ["IsPalindrome", "ReverseString", "Power", "GetMiddle", "SquareRoot"]



for i in range(len(common_names)):


    mean_pre = float(df_result.loc[df_result["Algorithm"] == common_names[i]+"-Pre"]["Correctness"].mean()*100)
    mean_post = float(df_result.loc[df_result["Algorithm"] == common_names[i]+"-Post"]["Correctness"].mean()*100)
    mean_pre_total += mean_pre
    mean_post_total += mean_post
    
    
    bar_df = bar_df.append(pd.DataFrame([[mean_pre, mean_post, "V" + str(i+1)]], columns=["Correctness-Pre", "Correctness-Post", "Algorithm"]))

    
#mean_pre_total /= len(common_names)
#mean_post_total /= len(common_names)

for i in range(len(algo_names_pre)):
    mean_pre = float(df_result.loc[df_result["Algorithm"]== algo_names_pre[i]]["Correctness"].mean()*100)
    mean_post = float(df_result.loc[df_result["Algorithm"]==algo_names_post[i]]["Correctness"].mean()*100)
    
    mean_pre_total += mean_pre
    mean_post_total += mean_post


mean_pre_total /= 10
mean_post_total /= 10

print(mean_pre_total)
print(mean_post_total)


bar_df = bar_df.append(pd.DataFrame([[mean_pre_total, mean_post_total, "Insgesamt"]], columns=["Correctness-Pre", "Correctness-Post", "Algorithm"]))
bar_df = bar_df.rename(columns={'Algorithm':'Programmverständnisaufgaben','Correctness-Pre': 'Korrektheit Pretest', 'Correctness-Post': 'Korrektheit Posttest'})
display(bar_df)


from scipy.stats import ttest_rel


# Python paired sample t-test
print(ttest_rel(bar_df["Korrektheit Pretest"], bar_df["Korrektheit Posttest"]))

bar_df = bar_df.set_index('Programmverständnisaufgaben')
ax = bar_df.plot.bar(ylabel='Prozent', rot=0)
plt.tight_layout()
ax.yaxis.set_ticks(np.arange(0, 120, 20))
ax.legend(loc="center left", bbox_to_anchor=(1.0, 0.5))
plt.savefig("results/behavioral/bar_correctness_of_compared_result.pdf", bbox_inches='tight', pad_inches=0.01)
# Out:
# 84.16666666666666
# 80.33333333333333
#    Korrektheit Pretest  Korrektheit Posttest Programmverständnisaufgaben
# 0            85.714286             85.714286                          V1
# 0            80.952381             90.476190                          V2
# 0            75.000000             70.000000                          V3
# 0            52.380952             42.857143                          V4
# 0            90.476190            100.000000                          V5
# 0            84.166667             80.333333                   Insgesamt
# Ttest_relResult(statistic=-0.03570040013686923, pvalue=0.9729026854114151)

# %%
A_rank = [0, 0, 1, 1, 1, 1]
import statistics
statistics.stdev(A_rank)
# Out:
# 0.5163977794943222

# %%
new_df = pd.DataFrame()

for algo in common_names:
    new_df = new_df.append(df_result.loc[df_result["Algorithm"]== algo + "-Pre"])
    new_df = new_df.append(df_result.loc[df_result["Algorithm"]== algo + "-Post"])

# %%
new_df['Algorithm'] = new_df['Algorithm'].replace({'CommonChars-Pre': 'Pretest', 'CommonChars-Post': 'Posttest', 
                         'ReverseArray-Pre': 'Pretest', 'ReverseArray-Post': 'Posttest',
                         'BinarySearchStrings-Pre': 'Pretest', 'BinarySearchStrings-Post' : 'Posttest',
                         'Multiples-Pre' : 'Pretest', 'Multiples-Post': 'Posttest',
                         'InsertionSort-Pre' : 'Pretest', 'InsertionSort-Post' : 'Posttest'})


new_df = new_df.rename(columns={'Algorithm':'Verständnisaufgaben','ResponseTime': 'Sekunden'})

# %%
ax = sns.boxplot(x="Verständnisaufgaben", y="Sekunden", data=new_df)
ax.set_xticklabels(ax.get_xticklabels())
plt.ylim(0, 400)
ax.set_xlabel("");

plt.tight_layout()
plt.savefig("results/behavioral/v_response_time_boxplot.pdf", bbox_inches='tight', pad_inches=0.01)

# %%
ax = sns.violinplot(x="Verständnisaufgaben", y="Sekunden", data=new_df)
ax.set_xticklabels(ax.get_xticklabels())
plt.ylim(0, 750)

ax.set_xlabel("");

plt.tight_layout()
plt.savefig("results/behavioral/v_response_time_violinplot.pdf", bbox_inches='tight', pad_inches=0.01)

# %%
ax = sns.boxplot(x="Verständnisaufgaben", y="Correctness", data=new_df)
ax.set_xticklabels(ax.get_xticklabels())
plt.ylim(0, 400)

plt.tight_layout()
plt.savefig("results/behavioral/v_.pdf", bbox_inches='tight', pad_inches=0.01)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-94-9ae99c6e0df9> in <module>
# ----> 1 ax = sns.boxplot(x="Verständnisaufgaben", y="Correctness", data=new_df)
#       2 ax.set_xticklabels(ax.get_xticklabels())
#       3 plt.ylim(0, 400)
#       4
#       5
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2246     kwargs.update(dict(whis=whis))
#    2247
# -> 2248     plotter.plot(ax, kwargs)
#    2249     return ax
#    2250
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in plot(self, ax, boxplot_kws)
#     507     def plot(self, ax, boxplot_kws):
#     508         """Make the plot."""
# --> 509         self.draw_boxplot(ax, boxplot_kws)
#     510         self.annotate_axes(ax)
#     511         if self.orient == "h":
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in draw_boxplot(self, ax, kws)
#     439                     continue
#     440
# --> 441                 artist_dict = ax.boxplot(box_data,
#     442                                          vert=vert,
#     443                                          patch_artist=True,
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in boxplot(self, x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder)
#    3681             bootstrap = rcParams['boxplot.bootstrap']
#    3682
# -> 3683         bxpstats = cbook.boxplot_stats(x, whis=whis, bootstrap=bootstrap,
#    3684                                        labels=labels, autorange=autorange)
#    3685         if notch is None:
#
# ~\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in boxplot_stats(X, whis, bootstrap, labels, autorange)
#    1178
#    1179         # medians and quartiles
# -> 1180         q1, med, q3 = np.percentile(x, [25, 50, 75])
#    1181
#    1182         # interquartile range
#
# <__array_function__ internals> in percentile(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\function_base.py in percentile(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3816     if not _quantile_is_valid(q):
#    3817         raise ValueError("Percentiles must be in the range [0, 100]")
# -> 3818     return _quantile_unchecked(
#    3819         a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3820
#
# ~\anaconda3\lib\site-packages\numpy\lib\function_base.py in _quantile_unchecked(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3935                         interpolation='linear', keepdims=False):
#    3936     """Assumes that q is in [0, 1], and is an ndarray"""
# -> 3937     r, k = _ureduce(a, func=_quantile_ureduce_func, q=q, axis=axis, out=out,
#    3938                     overwrite_input=overwrite_input,
#    3939                     interpolation=interpolation)
#
# ~\anaconda3\lib\site-packages\numpy\lib\function_base.py in _ureduce(a, func, **kwargs)
#    3513         keepdim = (1,) * a.ndim
#    3514
# -> 3515     r = func(a, **kwargs)
#    3516     return r, keepdim
#    3517
#
# ~\anaconda3\lib\site-packages\numpy\lib\function_base.py in _quantile_ureduce_func(***failed resolving arguments***)
#    4062         x_above = take(ap, indices_above, axis=0)
#    4063
# -> 4064         r = _lerp(x_below, x_above, weights_above, out=out)
#    4065
#    4066     # if any slice contained a nan, then all results on that slice are also nan
#
# ~\anaconda3\lib\site-packages\numpy\lib\function_base.py in _lerp(a, b, t, out)
#    3959 def _lerp(a, b, t, out=None):
#    3960     """ Linearly interpolate from a to b by a factor of t """
# -> 3961     diff_b_a = subtract(b, a)
#    3962     # asanyarray is a stop-gap until gh-13105
#    3963     lerp_interpolation = asanyarray(add(a, diff_b_a*t, out=out))
#
# TypeError: numpy boolean subtract, the `-` operator, is not supported, use the bitwise_xor, the `^` operator, or the logical_xor function instead.

# %%
bar_df = pd.DataFrame([],columns=["Correctness-Pre", "Correctness-Post", "Algorithm"])

mean_pre_total_different = 0
mean_post_total_different = 0

algo_names_pre = ["ContainsSubstring", "CountVowels", "CrossSum", "Swap", "GreatestCommonDivisor"]
algo_names_post = ["IsPalindrome", "ReverseString", "Power", "GetMiddle", "SquareRoot"]


for i in range(len(algo_names_pre)):
    mean_pre = float(df_result.loc[df_result["Algorithm"] == algo_names_pre[i]]["Correctness"].mean()*100)
    mean_post = float(df_result.loc[df_result["Algorithm"] == algo_names_post[i]]["Correctness"].mean()*100)
    bar_df = bar_df.append(pd.DataFrame([[mean_pre, mean_post, algo_names_pre[i]+"/"+algo_names_post[i]]], columns=["Correctness-Pre", "Correctness-Post", "Algorithm"]))
    mean_pre_total_different += mean_pre
    mean_post_total_different += mean_post

mean_pre_total_different /= len(common_names)
mean_post_total_different /= len(common_names)

bar_df = bar_df.append(pd.DataFrame([[mean_pre_total_different, mean_post_total_different, "Insgesamt"]], columns=["Correctness-Pre", "Correctness-Post", "Algorithm"]))
display(bar_df["Algorithm"])

bar_df["Algorithm"] = bar_df["Algorithm"].replace({'ContainsSubstring/IsPalindrome': 'CS/ IP', 'CountVowels/ReverseString' : 'CW/ RV', 'GreatestCommonDivisor/SquareRoot' : 'GCD/ SR'})

bar_df = bar_df.rename(columns={'Algorithm':'Algorithmus','Correctness-Pre': 'Korrektheit Pretest', 'Correctness-Post': 'Korrektheit Posttest'})

display(bar_df)
bar_df = bar_df.set_index('Algorithmus')
ax = bar_df.plot.bar(rot=290)
plt.tight_layout()
ax.legend(loc="center left", bbox_to_anchor=(1.0, 0.5))
plt.savefig("results/behavioral/bar_correctness_of_compared_result_all.pdf", bbox_inches='tight', pad_inches=0.1)
# Out:
# 0      ContainsSubstring/IsPalindrome
# 0           CountVowels/ReverseString
# 0                      CrossSum/Power
# 0                      Swap/GetMiddle
# 0    GreatestCommonDivisor/SquareRoot
# 0                           Insgesamt
# Name: Algorithm, dtype: object
#    Korrektheit Pretest  Korrektheit Posttest     Algorithmus
# 0            85.714286            100.000000          CS/ IP
# 0           100.000000             90.476190          CW/ RV
# 0            90.476190             90.476190  CrossSum/Power
# 0            90.476190             47.619048  Swap/GetMiddle
# 0            90.476190             85.714286         GCD/ SR
# 0            91.428571             82.857143       Insgesamt

# %%
bar_df = pd.DataFrame([],columns=["ResponseTime-Pre", "ResponseTime-Post", "Algorithm"])

mean_pre_total = 0
mean_post_total = 0


for algo_name in common_names:
   
   
    mean_pre = float(df_result.loc[df_result["Algorithm"] == algo_name+"-Pre"]["ResponseTime"].mean())
    mean_post = float(df_result.loc[df_result["Algorithm"] == algo_name+"-Post"]["ResponseTime"].mean())
    mean_pre_total += mean_pre
    mean_post_total += mean_post
    
    bar_df = bar_df.append(pd.DataFrame([[mean_pre, mean_post, algo_name]], columns=["ResponseTime-Pre", "ResponseTime-Post", "Algorithm"]))

mean_pre_total /= len(common_names)
mean_post_total /= len(common_names)

bar_df = bar_df.append(pd.DataFrame([[mean_pre_total, mean_post_total, "Insgesamt"]], columns=["ResponseTime-Pre", "ResponseTime-Post", "Algorithm"]))
bar_df = bar_df.rename(columns={'Algorithm':'Algorithmus','ResponseTime-Pre': 'Beantwortungszeit Pretest', 'ResponseTime-Post': 'Beantwortungszeit Posttest'})

from scipy.stats import ttest_rel


display(bar_df)
bar_df = bar_df.set_index('Algorithmus')
ax = bar_df.plot.bar(ylabel='Sekunden', rot=290)
ax.yaxis.set_ticks(np.arange(0, 200, 30))
plt.tight_layout()
ax.legend(loc="center left", bbox_to_anchor=(1.0, 0.5))
plt.savefig("results/behavioral/bar_response_time_common.pdf", bbox_inches='tight', pad_inches=0.01)
# Out:
#    Beantwortungszeit Pretest  Beantwortungszeit Posttest          Algorithmus
# 0                 121.333333                   73.761905          CommonChars
# 0                 121.190476                   72.476190         ReverseArray
# 0                 180.857143                   96.619048  BinarySearchStrings
# 0                 125.857143                  112.000000            Multiples
# 0                 119.047619                   87.523810        InsertionSort
# 0                 133.657143                   88.476190            Insgesamt

# %%
bar_df = pd.DataFrame([],columns=["ResponseTime-Pre", "ResponseTime-Post", "Algorithm"])

mean_pre_total = 0
mean_post_total = 0


for algo_name in common_names:
   
   
    mean_pre = float(df_result.loc[df_result["Algorithm"] == algo_name+"-Pre"]["Correctness"].mean())
    mean_post = float(df_result.loc[df_result["Algorithm"] == algo_name+"-Post"]["Correctness"].mean())
    mean_pre_total += mean_pre
    mean_post_total += mean_post
    
    bar_df = bar_df.append(pd.DataFrame([[mean_pre, mean_post, algo_name]], columns=["ResponseTime-Pre", "ResponseTime-Post", "Algorithm"]))

mean_pre_total /= len(common_names)
mean_post_total /= len(common_names)

bar_df = bar_df.append(pd.DataFrame([[mean_pre_total, mean_post_total, "Insgesamt"]], columns=["ResponseTime-Pre", "ResponseTime-Post", "Algorithm"]))
bar_df = bar_df.rename(columns={'Algorithm':'Algorithmus','ResponseTime-Pre': 'Beantwortungszeit Pretest', 'ResponseTime-Post': 'Beantwortungszeit Posttest'})

from scipy.stats import ttest_rel


display(bar_df)
bar_df = bar_df.set_index('Algorithmus')
ax = bar_df.plot.bar(ylabel='Sekunden', rot=290)
ax.yaxis.set_ticks(np.arange(0, 200, 30))
plt.tight_layout()
ax.legend(loc="center left", bbox_to_anchor=(1.0, 0.5))
plt.savefig("results/behavioral/bar_response_time_common.pdf", bbox_inches='tight', pad_inches=0.01)
# Out:
#    Beantwortungszeit Pretest  Beantwortungszeit Posttest          Algorithmus
# 0                   0.857143                    0.857143          CommonChars
# 0                   0.809524                    0.904762         ReverseArray
# 0                   0.714286                    0.714286  BinarySearchStrings
# 0                   0.523810                    0.428571            Multiples
# 0                   0.904762                    1.000000        InsertionSort
# 0                   0.761905                    0.780952            Insgesamt

# %%
bar_df = pd.DataFrame([],columns=["ResponseTime-Pre", "ResponseTime-Post", "Algorithm"])

mean_pre_total = 0
mean_post_total = 0

mean_pre_total_different = 0
mean_post_total_different = 0

algo_names_pre = ["ContainsSubstring", "CountVowels", "CrossSum", "Swap", "GreatestCommonDivisor"]
algo_names_post = ["IsPalindrome", "ReverseString", "Power", "GetMiddle", "SquareRoot"]

print(df_result.loc[(df_result["Algorithm"] == "GetMiddle") & (df_result["Correctness"] == True)]["ResponseTime"].describe())
print(df_result.loc[df_result["Algorithm"] == "GetMiddle"]["ResponseTime"].describe())


    #number_of_corrects = len(df.loc[(df["Correctness"] == True) & (df["Unique Code"]== students[i])])


print

for i in range(len(algo_names_pre)):
    mean_pre = float(df_result.loc[df_result["Algorithm"] == algo_names_pre[i]]["ResponseTime"].mean())
    mean_post = float(df_result.loc[df_result["Algorithm"] == algo_names_post[i]]["ResponseTime"].mean())
    bar_df = bar_df.append(pd.DataFrame([[mean_pre, mean_post, algo_names_pre[i]+"/"+algo_names_post[i]]], columns=["ResponseTime-Pre", "ResponseTime-Post", "Algorithm"]))
    mean_pre_total_different += mean_pre
    mean_post_total_different += mean_post

mean_pre_total_different /= len(common_names)
mean_post_total_different /= len(common_names)

bar_df = bar_df.append(pd.DataFrame([[mean_pre_total_different, mean_post_total_different, "Insgesamt"]], columns=["ResponseTime-Pre", "ResponseTime-Post", "Algorithm"]))
display(bar_df["Algorithm"])

bar_df["Algorithm"] = bar_df["Algorithm"].replace({'ContainsSubstring/IsPalindrome': 'CS/ IP', 'CountVowels/ReverseString' : 'CW/ RV', 'GreatestCommonDivisor/SquareRoot' : 'GCD/ SR'})

bar_df = bar_df.rename(columns={'Algorithm':'Algorithmus','ResponseTime-Pre': 'Beantwortungszeit Pretest', 'ResponseTime-Post': 'Beantwortungszeit Posttest'})

print(mean_pre_total_different, mean_post_total_different)

print(mean_pre_total_different/mean_post_total_different)

display(bar_df)
bar_df = bar_df.set_index('Algorithmus')
ax = bar_df.plot.bar(ylabel='Sekunden', rot=290)
ax.yaxis.set_ticks(np.arange(0, 200, 30))
plt.tight_layout()
ax.legend(loc="center left", bbox_to_anchor=(1.0, 0.5))
plt.savefig("results/behavioral/bar_response_time_different.pdf", bbox_inches='tight', pad_inches=0.01)
# Out:
# count     10.000000
# mean     115.600000
# std       53.267042
# min       47.000000
# 25%       77.000000
# 50%      113.000000
# 75%      135.250000
# max      201.000000
# Name: ResponseTime, dtype: float64
# count     21.000000
# mean     131.904762
# std       92.854135
# min       47.000000
# 25%       78.000000
# 50%      102.000000
# 75%      130.000000
# max      457.000000
# Name: ResponseTime, dtype: float64
# 0      ContainsSubstring/IsPalindrome
# 0           CountVowels/ReverseString
# 0                      CrossSum/Power
# 0                      Swap/GetMiddle
# 0    GreatestCommonDivisor/SquareRoot
# 0                           Insgesamt
# Name: Algorithm, dtype: object
# 103.45714285714287 70.78095238095237
# 1.4616523143164697
#    Beantwortungszeit Pretest  Beantwortungszeit Posttest     Algorithmus
# 0                 152.142857                   54.857143          CS/ IP
# 0                  54.857143                   33.904762          CW/ RV
# 0                 123.904762                   53.666667  CrossSum/Power
# 0                  50.714286                  131.904762  Swap/GetMiddle
# 0                 135.666667                   79.571429         GCD/ SR
# 0                 103.457143                   70.780952       Insgesamt

# %%
bar_df = pd.DataFrame([],columns=["Correctness-Pre", "Correctness-Post", "Difficulty-Pre", "Difficulty-Post", "Algorithm"])

mean_pre_total_different = 0
mean_post_total_different = 0
difficulty_pre_total_different = 0
difficulty_post_total_different = 0

algo_names_pre = ["ContainsSubstring", "CountVowels", "CrossSum", "Swap", "GreatestCommonDivisor"]
algo_names_post = ["IsPalindrome", "ReverseString", "Power", "GetMiddle", "SquareRoot"]


for i in range(len(algo_names_pre)):
    mean_pre = float(df_result.loc[df_result["Algorithm"] == algo_names_pre[i]]["Correctness"].mean()*100)
    difficulty_pre = float(df_result.loc[df_result["Algorithm"] == algo_names_pre[i]]["Difficulty"].mean())
    difficulty_post = float(df_result.loc[df_result["Algorithm"] == algo_names_post[i]]["Difficulty"].mean())
    mean_post = float(df_result.loc[df_result["Algorithm"] == algo_names_post[i]]["Correctness"].mean()*100)
    bar_df = bar_df.append(pd.DataFrame([[mean_pre, mean_post, difficulty_pre, difficulty_post, algo_names_pre[i]+"/"+algo_names_post[i]]], 
                                        columns=["Correctness-Pre", "Correctness-Post", "Difficulty-Pre", "Difficulty-Post", "Algorithm"]))
    mean_pre_total_different += mean_pre
    mean_post_total_different += mean_post
    difficulty_pre_total_different += difficulty_pre
    difficulty_post_total_different += difficulty_post

mean_pre_total_different /= len(common_names)
mean_post_total_different /= len(common_names)
difficulty_pre_total_different /= len(common_names)
difficulty_post_total_different /= len(common_names)

bar_df = bar_df.append(pd.DataFrame([[mean_pre_total_different, mean_post_total_different, difficulty_pre_total_different, difficulty_post_total_different, "Insgesamt"]], 
                                    columns=["Correctness-Pre", "Correctness-Post", "Difficulty-Pre", "Difficulty-Post", "Algorithm"]))
display(bar_df["Algorithm"])

bar_df["Algorithm"] = bar_df["Algorithm"].replace({'ContainsSubstring/IsPalindrome': 'CS/ IP', 'CountVowels/ReverseString' : 'CW/ RV', 'GreatestCommonDivisor/SquareRoot' : 'GCD/ SR'})

bar_df = bar_df.rename(columns={'Algorithm':'Algorithmus','Correctness-Pre': 'Korrektheit Pretest', 'Correctness-Post': 'Korrektheit Posttest'})

display(bar_df)
bar_df = bar_df.set_index('Algorithmus')
ax = bar_df.plot.bar(rot=290)
plt.tight_layout()
ax.legend(loc="center left", bbox_to_anchor=(1.0, 0.5))
plt.savefig("results/behavioral/bar_correctness_of_compared_result_all.pdf", bbox_inches='tight', pad_inches=0.1)
# Out:
# 0      ContainsSubstring/IsPalindrome
# 0           CountVowels/ReverseString
# 0                      CrossSum/Power
# 0                      Swap/GetMiddle
# 0    GreatestCommonDivisor/SquareRoot
# 0                           Insgesamt
# Name: Algorithm, dtype: object
#    Korrektheit Pretest  Korrektheit Posttest  Difficulty-Pre  Difficulty-Post  \
# 0            85.714286            100.000000        1.666667         1.047619
# 0           100.000000             90.476190        1.047619         1.000000
# 0            90.476190             90.476190        1.142857         1.000000
# 0            90.476190             47.619048        1.047619         1.380952
# 0            90.476190             85.714286        1.238095         1.285714
# 0            91.428571             82.857143        1.228571         1.142857
#
#       Algorithmus
# 0          CS/ IP
# 0          CW/ RV
# 0  CrossSum/Power
# 0  Swap/GetMiddle
# 0         GCD/ SR
# 0       Insgesamt

# %%
bar_df = pd.DataFrame([],columns=["Correctness-Pre", "Correctness-Post", "Algorithm"])


common_chars_df = pd.DataFrame([],columns=["Correctness-Pre", "Correctness-Post", "Algorithm"])


mean_pre_total = 0
mean_post_total = 0
mean_pre_total_different = 0
mean_post_total_different = 0

algo_names_pre = ["ContainsSubstring", "CountVowels", "CrossSum", "Swap", "GreatestCommonDivisor"]
algo_names_post = ["IsPalindrome", "ReverseString", "Power", "GetMiddle", "SquareRoot"]


#mean_pre = df_result.loc[df_result["Algorithm"]=="CommonChars-Pre"]["Correctness"]
#mean_post = df_result.loc[df_result["Algorithm"]=="CommonChars-Post"]["Correctness"]

#common_chars_df = common_chars_df.append(pd.DataFrame([[mean_pre, mean_post, "Common Chars"]], columns=["Correctness-Pre", "Correctness-Post", "Algorithm"]))

df_result["Correctness"] = df_result["Correctness"].astype(int)

# Python paired sample t-test

for algo_name in common_names:
    mean_pre = float(df_result.loc[df_result["Algorithm"] == algo_name+"-Pre"]["Correctness"].mean()*100)
    mean_post = float(df_result.loc[df_result["Algorithm"] == algo_name+"-Post"]["Correctness"].mean()*100)
    bar_df = bar_df.append(pd.DataFrame([[mean_pre, mean_post, algo_name]], columns=["Correctness-Pre", "Correctness-Post", "Algorithm"]))

    mean_pre_total += mean_pre
    mean_post_total += mean_post
    


for i in range(len(algo_names_pre)):
    mean_pre = float(df_result.loc[df_result["Algorithm"] == algo_names_pre[i]]["Correctness"].mean()*100)
    mean_post = float(df_result.loc[df_result["Algorithm"] == algo_names_post[i]]["Correctness"].mean()*100)
    bar_df = bar_df.append(pd.DataFrame([[mean_pre, mean_post, algo_names_pre[i]+"/"+algo_names_post[i]]], columns=["Correctness-Pre", "Correctness-Post", "Algorithm"]))
    mean_pre_total_different += mean_pre
    mean_post_total_different += mean_post

mean_pre_total /= 5
mean_post_total /= 5
mean_pre_total_different /= 5
mean_post_total_different /= 5

bar_df = bar_df.append(pd.DataFrame([[mean_pre_total, mean_post_total, "Insgesamt-gleich"]], columns=["Correctness-Pre", "Correctness-Post", "Algorithm"]))
bar_df = bar_df.append(pd.DataFrame([[mean_pre_total_different, mean_post_total_different, "Insgesamt-unterschiedlich"]], columns=["Correctness-Pre", "Correctness-Post", "Algorithm"]))
bar_df = bar_df.append(pd.DataFrame([[(mean_pre_total_different + mean_pre_total)/2, (mean_post_total_different + mean_post_total)/2, "Insgesamt"]], columns=["Correctness-Pre", "Correctness-Post", "Algorithm"]))
#common_chars_df = common_chars_df.append(pd.DataFrame([[mean_pre_total, mean_post_total, "Insgesamt-gleich"]], columns=["Correctness-Pre", "Correctness-Post", "Algorithm"]))
#common_chars_df = common_chars_df.append(pd.DataFrame([[mean_pre_total_different, mean_post_total, "Insgesamt-gleich"]], columns=["Correctness-Pre", "Correctness-Post", "Algorithm"]))


#display(df_result)



#pre_all = bar_df[bar_df["Algorithm"].isin(["CommonChars-Pre", "ReverseArray-Pre", "BinarySearchStrings-Pre"])]
#df.query('a in ["a", "b", "c"]')
#print(bar_df[bar_df["Algorithm"]])

#print(pre_gcd)
from scipy.stats import mannwhitneyu


  
# perform mann whitney test
#stat, p_value = mannwhitneyu(pre_common_chars_time, post_common_chars_time)
#print('Statistics=%.2f, p=%f' % (stat, p_value))
# Level of significance
#alpha = 0.05
# conclusion
#if p_value < alpha:
#    print('Reject Null Hypothesis (Significant difference between two samples)')
#else:
#    print('Do not Reject Null Hypothesis (No significant difference between two samples)')

from pingouin import mwu
from pingouin import wilcoxon
#print(wilcoxon(pre_same_time, post_same_time))

for i in range(len(post_list_same)):
    tmp_pre = df_result[df_result["Algorithm"]==pre_list_same[i]]["Correctness"]
    tmp_post = df_result[df_result["Algorithm"]==post_list_same[i]]["Correctness"]
    s, p = stats.shapiro(tmp_pre)
    #ttest <= 0.05 = signifikant
    #print(stats.ttest_rel(tmp_pre, tmp_post))
    #print("Shapiro")
    #print(s, p)
    


bar_df["Algorithm"] = bar_df["Algorithm"].replace({'ContainsSubstring/IsPalindrome': 'CS/ IP', 'CountVowels/ReverseString' : 'CW/ RV', 'GreatestCommonDivisor/SquareRoot' : 'GCD/ SR'})
bar_df = bar_df.rename(columns={'Algorithm':'Algorithmus','Correctness-Pre': 'Korrektheit Pretest', 'Correctness-Post': 'Korrektheit Posttest'})


bar_df = bar_df.set_index('Algorithmus')
ax = bar_df.plot.bar(ylabel='Prozent', rot=290, title="Das Ergebnis derselben Algorithmen im Pre- und Posttest im Vergleich\n")
plt.tight_layout()
ax.legend(loc="center left", bbox_to_anchor=(1.0, 0.5))
plt.savefig("results/behavioral/correctness_all.pdf", bbox_inches='tight', pad_inches=0.01)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-49965f8bb7fd> in <module>
#      80 #print(wilcoxon(pre_same_time, post_same_time))
#      81
# ---> 82 for i in range(len(post_list_same)):
#      83     tmp_pre = df_result[df_result["Algorithm"]==pre_list_same[i]]["Correctness"]
#      84     tmp_post = df_result[df_result["Algorithm"]==post_list_same[i]]["Correctness"]
#
# NameError: name 'post_list_same' is not defined

# %%
beginner = ['6aOGho', '8aRHui', '1aMLsa', '5nDFhi', '9aBWha', '1eASaa',
            '8lHHsu', '4aRGür', '2eTGer', '1nCWte', '4iMVha']
advanced = ['1nUSüa', '2nGAhe', '1aTGsa', '6aJGhh', '6vEHhi', '9oMWun',
            '3rCHei', '4uCGer', '5uHJei', '5nFKho']

print(len(beginner))
print(len(advanced))

df_beginner = pd.DataFrame()

df_advanced = pd.DataFrame()
    

for code in beginner:
    tmp = df_result.loc[df_result["Unique Code"]==code]
    df_beginner = df_beginner.append(tmp)


for code in advanced:
    tmp_pre = df_pre.loc[df_pre["Unique Code"]==code]
    tmp_post = df_post.loc[df_post["Unique Code"]==code]
    df_advanced_pre = df_advanced_pre.append(tmp_pre)
    df_advanced_post = df_advanced_post.append(tmp_post)
    


bss_pre = df_result.loc[df_result["Algorithm"] == "BinarySearchStrings-Pre"]
bss_post = df_result.loc[df_result["Algorithm"] == "BinarySearchStrings-Post"]

bss_pre_beginner = df_beginner_pre.loc[df_beginner_pre["Algorithm"] == "BinarySearchStrings-Pre"]
bss_post_beginner = df_beginner_post.loc[df_beginner_post["Algorithm"] == "BinarySearchStrings-Post"]

tmp_pre_beginner = bss_pre_beginner.nlargest(11, 'ResponseTime')
tmp_post_beginner = bss_post_beginner.nlargest(11, 'ResponseTime')

tmp_pre = bss_pre.nlargest(21, 'ResponseTime')
tmp_post = bss_post.nlargest(21, 'ResponseTime')


print("Beginner")
print(tmp_pre_beginner[["Unique Code","Algorithm","ResponseTime", "Correctness"]])


print("\nAll")
print(tmp_pre[["Unique Code", "Algorithm", "ResponseTime", "Correctness"]])



print(tmp_post[["Unique Code","Algorithm","ResponseTime", "Correctness"]])
# Out:
# 11
# 10
# Beginner
#     Unique Code                Algorithm  ResponseTime  Correctness
# 213      6aOGho  BinarySearchStrings-Pre           661         True
# 244      4aRGür  BinarySearchStrings-Pre           292         True
# 221      8aRHui  BinarySearchStrings-Pre           179         True
# 249      1nCWte  BinarySearchStrings-Pre           156        False
# 236      1eASaa  BinarySearchStrings-Pre           146         True
# 240      8lHHsu  BinarySearchStrings-Pre           144         True
# 258      4iMVha  BinarySearchStrings-Pre           122        False
# 246      2eTGer  BinarySearchStrings-Pre           120        False
# 226      9aBWha  BinarySearchStrings-Pre           113        False
# 224      1aMLsa  BinarySearchStrings-Pre            44         True
# 225      5nDFhi  BinarySearchStrings-Pre            41         True
#
# All
#     Unique Code                Algorithm  ResponseTime  Correctness
# 213      6aOGho  BinarySearchStrings-Pre           661            1
# 256      5nFKho  BinarySearchStrings-Pre           345            1
# 244      4aRGür  BinarySearchStrings-Pre           292            1
# 250      3rCHei  BinarySearchStrings-Pre           256            0
# 242      9oMWun  BinarySearchStrings-Pre           239            1
# 212      2nGAhe  BinarySearchStrings-Pre           202            1
# 220      6aJGhh  BinarySearchStrings-Pre           202            1
# 221      8aRHui  BinarySearchStrings-Pre           179            1
# 249      1nCWte  BinarySearchStrings-Pre           156            0
# 236      1eASaa  BinarySearchStrings-Pre           146            1
# 217      1aTGsa  BinarySearchStrings-Pre           146            1
# 240      8lHHsu  BinarySearchStrings-Pre           144            1
# 252      4uCGer  BinarySearchStrings-Pre           139            1
# 255      5uHJei  BinarySearchStrings-Pre           137            1
# 258      4iMVha  BinarySearchStrings-Pre           122            0
# 246      2eTGer  BinarySearchStrings-Pre           120            0
# 226      9aBWha  BinarySearchStrings-Pre           113            0
# 239      6vEHhi  BinarySearchStrings-Pre            57            0
# 208      1nUSüa  BinarySearchStrings-Pre            57            1
# 224      1aMLsa  BinarySearchStrings-Pre            44            1
# 225      5nDFhi  BinarySearchStrings-Pre            41            1
#     Unique Code                 Algorithm  ResponseTime  Correctness
# 94       6vEHhi  BinarySearchStrings-Post           302            1
# 104      2nGAhe  BinarySearchStrings-Post           206            0
# 88       6aOGho  BinarySearchStrings-Post           196            1
# 107      5nFKho  BinarySearchStrings-Post           195            0
# 99       2eTGer  BinarySearchStrings-Post           156            0
# 109      5uHJei  BinarySearchStrings-Post           116            1
# 103      3rCHei  BinarySearchStrings-Post           108            0
# 90       8aRHui  BinarySearchStrings-Post            78            1
# 106      1eASaa  BinarySearchStrings-Post            76            1
# 91       8lHHsu  BinarySearchStrings-Post            68            1
# 95       6aJGhh  BinarySearchStrings-Post            68            1
# 89       4iMVha  BinarySearchStrings-Post            62            0
# 92       9oMWun  BinarySearchStrings-Post            61            1
# 100      4uCGer  BinarySearchStrings-Post            54            1
# 102      4aRGür  BinarySearchStrings-Post            53            1
# 105      1nCWte  BinarySearchStrings-Post            46            0
# 97       1aTGsa  BinarySearchStrings-Post            45            1
# 98       1nUSüa  BinarySearchStrings-Post            44            1
# 96       5nDFhi  BinarySearchStrings-Post            35            1
# 101      1aMLsa  BinarySearchStrings-Post            31            1
# 108      9aBWha  BinarySearchStrings-Post            29            1

# %%
bar_df = pd.DataFrame([],columns=["Correctness-Pre", "Correctness-Post", "Algorithm"])

mean_pre_total = 0
mean_post_total = 0


for algo_name in common_names:
    print("XXX", df_beginner_pre.loc[df_beginner_pre["Algorithm"] == algo_name+"-Pre"]["ResponseTime"])
    mean_pre = float(df_beginner_pre.loc[df_beginner_pre["Algorithm"] == algo_name+"-Pre"]["Correctness"].mean()*100)
    mean_post = float(df_beginner_post.loc[df_beginner_post["Algorithm"] == algo_name+"-Post"]["Correctness"].mean()*100)
    mean_pre_total += mean_pre
    mean_post_total += mean_post
    
    bar_df = bar_df.append(pd.DataFrame([[mean_pre, mean_post, algo_name]], columns=["Correctness-Pre", "Correctness-Post", "Algorithm"]))

mean_pre_total /= len(common_names)
mean_post_total /= len(common_names)

bar_df = bar_df.append(pd.DataFrame([[mean_pre_total, mean_post_total, "Insgesamt"]], columns=["Correctness-Pre", "Correctness-Post", "Algorithm"]))
bar_df = bar_df.rename(columns={'Algorithm':'Algorithmus','Correctness-Pre': 'Korrektheit Pretest', 'Correctness-Post': 'Korrektheit Posttest'})
display(bar_df)


bar_df = bar_df.set_index('Algorithmus')
ax = bar_df.plot.bar(ylabel='Prozent', rot=290, title="Das Ergebnis derselben Algorithmen im Pre- und Posttest im Vergleich\n")
plt.tight_layout()
ax.legend(loc="center left", bbox_to_anchor=(1.0, 0.5))
plt.savefig("results/behavioral/bar_correctness_of_beginner.pdf", bbox_inches='tight', pad_inches=0.01)

# %%
bar_df = pd.DataFrame([],columns=["Correctness-Pre", "Correctness-Post", "Algorithm"])

mean_pre_total = 0
mean_post_total = 0


for algo_name in common_names:
    mean_pre = float(df_advanced_pre.loc[df_advanced_pre["Algorithm"] == algo_name+"-Pre"]["Correctness"].mean()*100)
    mean_post = float(df_advanced_post.loc[df_advanced_post["Algorithm"] == algo_name+"-Post"]["Correctness"].mean()*100)
    mean_pre_total += mean_pre
    mean_post_total += mean_post
    
    bar_df = bar_df.append(pd.DataFrame([[mean_pre, mean_post, algo_name]], columns=["Correctness-Pre", "Correctness-Post", "Algorithm"]))

mean_pre_total /= len(common_names)
mean_post_total /= len(common_names)

bar_df = bar_df.append(pd.DataFrame([[mean_pre_total, mean_post_total, "Insgesamt"]], columns=["Correctness-Pre", "Correctness-Post", "Algorithm"]))
bar_df = bar_df.rename(columns={'Algorithm':'Algorithmus','Correctness-Pre': 'Korrektheit Pretest', 'Correctness-Post': 'Korrektheit Posttest'})
display(bar_df)


bar_df = bar_df.set_index('Algorithmus')
ax = bar_df.plot.bar(ylabel='Prozent', rot=290, title="Das Ergebnis derselben Algorithmen im Pre- und Posttest im Vergleich\n")
plt.tight_layout()
ax.legend(loc="center left", bbox_to_anchor=(1.0, 0.5))
plt.savefig("results/behavioral/bar_correctness_of_advanced.pdf", bbox_inches='tight', pad_inches=0.01)

# %%
bar_df = pd.DataFrame([],columns=["Correctness-Pre", "Correctness-Post", "Algorithm"])

mean_pre_total_different = 0
mean_post_total_different = 0

algo_names_pre = ["ContainsSubstring", "CountVowels", "CrossSum", "Swap", "GreatestCommonDivisor"]
algo_names_post = ["IsPalindrome", "ReverseString", "Power", "GetMiddle", "SquareRoot"]


for i in range(len(algo_names_pre)):
    mean_pre = float(df_beginner_pre.loc[df_beginner_pre["Algorithm"] == algo_names_pre[i]]["Correctness"].mean()*100)
    mean_post = float(df_beginner_post.loc[df_beginner_post["Algorithm"] == algo_names_post[i]]["Correctness"].mean()*100)
    bar_df = bar_df.append(pd.DataFrame([[mean_pre, mean_post, algo_names_pre[i]+"/"+algo_names_post[i]]], columns=["Correctness-Pre", "Correctness-Post", "Algorithm"]))
    mean_pre_total_different += mean_pre
    mean_post_total_different += mean_post

mean_pre_total_different /= len(common_names)
mean_post_total_different /= len(common_names)

bar_df = bar_df.append(pd.DataFrame([[mean_pre_total_different, mean_post_total_different, "Insgesamt"]], columns=["Correctness-Pre", "Correctness-Post", "Algorithm"]))
display(bar_df["Algorithm"])

bar_df["Algorithm"] = bar_df["Algorithm"].replace({'ContainsSubstring/IsPalindrome': 'CS/ IP', 'CountVowels/ReverseString' : 'CW/ RV', 'GreatestCommonDivisor/SquareRoot' : 'GCD/ SR'})

bar_df = bar_df.rename(columns={'Algorithm':'Algorithmus','Correctness-Pre': 'Korrektheit Pretest', 'Correctness-Post': 'Korrektheit Posttest'})

display(bar_df)
bar_df = bar_df.set_index('Algorithmus')
ax = bar_df.plot.bar(rot=290)
plt.tight_layout()
ax.legend(loc="center left", bbox_to_anchor=(1.0, 0.5))
plt.savefig("results/behavioral/bar_correctness_of_compared_beginner_all.pdf", bbox_inches='tight', pad_inches=0.1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-fc015e7b7e7f> in <module>
#       9
#      10 for i in range(len(algo_names_pre)):
# ---> 11     mean_pre = float(df_beginner_pre.loc[df_beginner_pre["Algorithm"] == algo_names_pre[i]]["Correctness"].mean()*100)
#      12     mean_post = float(df_beginner_post.loc[df_beginner_post["Algorithm"] == algo_names_post[i]]["Correctness"].mean()*100)
#      13     bar_df = bar_df.append(pd.DataFrame([[mean_pre, mean_post, algo_names_pre[i]+"/"+algo_names_post[i]]], columns=["Correctness-Pre", "Correctness-Post", "Algorithm"]))
#
# NameError: name 'df_beginner_pre' is not defined

# %%
bar_df = pd.DataFrame([],columns=["Correctness-Pre", "Correctness-Post", "Algorithm"])

mean_pre_total_different = 0
mean_post_total_different = 0

algo_names_pre = ["ContainsSubstring", "CountVowels", "CrossSum", "Swap", "GreatestCommonDivisor"]
algo_names_post = ["IsPalindrome", "ReverseString", "Power", "GetMiddle", "SquareRoot"]


for i in range(len(algo_names_pre)):
    mean_pre = float(df_advanced_pre.loc[df_advanced_pre["Algorithm"] == algo_names_pre[i]]["Correctness"].mean()*100)
    mean_post = float(df_advanced_post.loc[df_advanced_post["Algorithm"] == algo_names_post[i]]["Correctness"].mean()*100)
    bar_df = bar_df.append(pd.DataFrame([[mean_pre, mean_post, algo_names_pre[i]+"/"+algo_names_post[i]]], columns=["Correctness-Pre", "Correctness-Post", "Algorithm"]))
    mean_pre_total_different += mean_pre
    mean_post_total_different += mean_post

mean_pre_total_different /= len(common_names)
mean_post_total_different /= len(common_names)

bar_df = bar_df.append(pd.DataFrame([[mean_pre_total_different, mean_post_total_different, "Insgesamt"]], columns=["Correctness-Pre", "Correctness-Post", "Algorithm"]))
display(bar_df["Algorithm"])

bar_df["Algorithm"] = bar_df["Algorithm"].replace({'ContainsSubstring/IsPalindrome': 'CS/ IP', 'CountVowels/ReverseString' : 'CW/ RV', 'GreatestCommonDivisor/SquareRoot' : 'GCD/ SR'})

bar_df = bar_df.rename(columns={'Algorithm':'Algorithmus','Correctness-Pre': 'Korrektheit Pretest', 'Correctness-Post': 'Korrektheit Posttest'})

display(bar_df)
bar_df = bar_df.set_index('Algorithmus')
ax = bar_df.plot.bar(rot=290)
plt.tight_layout()
ax.legend(loc="center left", bbox_to_anchor=(1.0, 0.5))
plt.savefig("results/behavioral/bar_correctness_of_compared_advanced_all.pdf", bbox_inches='tight', pad_inches=0.1)
# Out:
# 0      ContainsSubstring/IsPalindrome
# 0           CountVowels/ReverseString
# 0                      CrossSum/Power
# 0                      Swap/GetMiddle
# 0    GreatestCommonDivisor/SquareRoot
# 0                           Insgesamt
# Name: Algorithm, dtype: object
#    Korrektheit Pretest  Korrektheit Posttest     Algorithmus
# 0                 90.0                 100.0          CS/ IP
# 0                100.0                  90.0          CW/ RV
# 0                 80.0                  90.0  CrossSum/Power
# 0                 90.0                  50.0  Swap/GetMiddle
# 0                100.0                  90.0         GCD/ SR
# 0                 92.0                  84.0       Insgesamt

# %%
bar_df = pd.DataFrame([],columns=["Difficulty-Pre", "Difficulty-Post", "Algorithm"])

difficulty_pre_total_different = 0
difficulty_post_total_different = 0

algo_names_pre = ["ContainsSubstring", "CountVowels", "CrossSum", "Swap", "GreatestCommonDivisor"]
algo_names_post = ["IsPalindrome", "ReverseString", "Power", "GetMiddle", "SquareRoot"]


for i in range(len(algo_names_pre)):
    difficulty_pre = float(df_result.loc[df_result["Algorithm"] == algo_names_pre[i]]["Difficulty"].mean())
    difficulty_post = float(df_result.loc[df_result["Algorithm"] == algo_names_post[i]]["Difficulty"].mean())
    bar_df = bar_df.append(pd.DataFrame([[difficulty_pre, difficulty_post, algo_names_pre[i]+"/"+algo_names_post[i]]], 
                                        columns=["Difficulty-Pre", "Difficulty-Post", "Algorithm"]))
    difficulty_pre_total_different += difficulty_pre
    difficulty_post_total_different += difficulty_post

difficulty_pre_total_different /= len(common_names)
difficulty_post_total_different /= len(common_names)

bar_df = bar_df.append(pd.DataFrame([[difficulty_pre_total_different, difficulty_post_total_different, "Insgesamt"]], 
                                    columns=["Difficulty-Pre", "Difficulty-Post", "Algorithm"]))
display(bar_df["Algorithm"])

bar_df["Algorithm"] = bar_df["Algorithm"].replace({'ContainsSubstring/IsPalindrome': 'CS/ IP', 'CountVowels/ReverseString' : 'CW/ RV', 'GreatestCommonDivisor/SquareRoot' : 'GCD/ SR'})

bar_df = bar_df.rename(columns={'Algorithm':'Algorithmus','Difficulty-Pre': 'Schwierigkeit Pretest', 'Difficulty-Post': 'Schwierigkeit Posttest'})

display(bar_df)
bar_df = bar_df.set_index('Algorithmus')
ax = bar_df.plot.bar(rot=290)
plt.tight_layout()
ax.legend(loc="center left", bbox_to_anchor=(1.0, 0.5))
plt.savefig("results/behavioral/bar_correctness_of_compared_result_all.pdf", bbox_inches='tight', pad_inches=0.1)
# Out:
# 0      ContainsSubstring/IsPalindrome
# 0           CountVowels/ReverseString
# 0                      CrossSum/Power
# 0                      Swap/GetMiddle
# 0    GreatestCommonDivisor/SquareRoot
# 0                           Insgesamt
# Name: Algorithm, dtype: object
#    Schwierigkeit Pretest  Schwierigkeit Posttest     Algorithmus
# 0               1.666667                1.047619          CS/ IP
# 0               1.047619                1.000000          CW/ RV
# 0               1.142857                1.000000  CrossSum/Power
# 0               1.047619                1.380952  Swap/GetMiddle
# 0               1.238095                1.285714         GCD/ SR
# 0               1.228571                1.142857       Insgesamt

# %%
bar_df = pd.DataFrame([],columns=["Difficulty-Pre", "Difficulty-Post", "Algorithm"])

difficulty_pre_total = 0
difficulty_post_total = 0

difficulty_post_total_different = 0
difficulty_pre_total_different = 0

for i in range(len(algo_names_pre)):
    tmp_pre = float(df_result.loc[df_result["Algorithm"]==algo_names_pre[i]]["Difficulty"].mean())
    tmp_post = float(df_result.loc[df_result["Algorithm"]==algo_names_post[i]]["Difficulty"].mean())

    

    difficulty_pre_total_different += tmp_pre
    difficulty_post_total_different += tmp_post
    
print(difficulty_pre_total_different/5)
print(difficulty_post_total_different/5)

for algo_name in common_names:
    difficulty_pre = float(df_result.loc[df_result["Algorithm"] == algo_name+"-Pre"]["Difficulty"].mean())
    difficulty_post = float(df_result.loc[df_result["Algorithm"] == algo_name+"-Post"]["Difficulty"].mean())

    difficulty_pre_total += difficulty_pre
    difficulty_post_total += difficulty_post

    bar_df = bar_df.append(pd.DataFrame([[difficulty_pre, difficulty_post, algo_name]], columns=["Difficulty-Pre", "Difficulty-Post", "Algorithm"]))

difficulty_pre_total /= len(common_names)
difficulty_post_total /= len(common_names)

bar_df = bar_df.append(pd.DataFrame([[difficulty_pre_total, difficulty_post_total, "Insgesamt"]], 
                                    columns=["Difficulty-Pre", "Difficulty-Post", "Algorithm"]))
bar_df = bar_df.rename(columns={'Algorithm':'Algorithmus','Difficulty-Pre': 'Schwierigkeit Pretest', 'Difficulty-Post': 'Schwierigkeit Posttest'})
display(bar_df)


bar_df = bar_df.set_index('Algorithmus')
ax = bar_df.plot.bar(ylabel='Schwierigkeit', rot=290, title="Das Ergebnis derselben Algorithmen im Pre- und Posttest im Vergleich\n")
plt.tight_layout()
ax.legend(loc="center left", bbox_to_anchor=(1.0, 0.5))
plt.savefig("results/behavioral/bar_correctness_of_advanced.pdf", bbox_inches='tight', pad_inches=0.01)
# Out:
# 1.2285714285714286
# 1.1428571428571428
#    Schwierigkeit Pretest  Schwierigkeit Posttest          Algorithmus
# 0               1.142857                1.000000          CommonChars
# 0               1.571429                1.238095         ReverseArray
# 0               1.750000                1.450000  BinarySearchStrings
# 0               1.190476                1.238095            Multiples
# 0               1.619048                1.523810        InsertionSort
# 0               1.454762                1.290000            Insgesamt
