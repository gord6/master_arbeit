# %%
import pandas as pd
import seaborn as sns
import collections

# %%
config_datasheet = 'data/raw/Vokabeltraining.xlsx'
pre_datasheet = "results/data_of_all_removed.xlsx"
unique_code_datasheet = "results/behavioral/compare/compare.xlsx"

# %%
raw_if = pd.read_excel(config_datasheet, sheet_name ="If")
raw_for = pd.read_excel(config_datasheet, sheet_name= "For")
raw_while = pd.read_excel(config_datasheet, sheet_name="While")
raw_do_while = pd.read_excel(config_datasheet, sheet_name="Do-While")
raw_pre = pd.read_excel(pre_datasheet)
raw_unique_codes = pd.read_excel(unique_code_datasheet)


df_if = pd.DataFrame(raw_if)
df_for = pd.DataFrame(raw_for)
df_while = pd.DataFrame(raw_while)
df_do_while = pd.DataFrame(raw_do_while)
df_pre = pd.DataFrame(raw_pre)
df_unique_codes = pd.DataFrame(raw_unique_codes)
df_unique_codes
# Out:
#      Unnamed: 0 Unique Code  ResponseTime                Algorithm  Flag  \
# 0            16      1aMLsa           174          CommonChars-Pre   NaN
# 1            68      1aMLsa           107        ContainsSubstring   NaN
# 2           120      1aMLsa            61              CountVowels   NaN
# 3           172      1aMLsa           106         ReverseArray-Pre   NaN
# 4           224      1aMLsa            44  BinarySearchStrings-Pre   NaN
# ..          ...         ...           ...                      ...   ...
# 415         114      9oMWun            59           Multiples-Post   NaN
# 416         136      9oMWun            60                    Power   NaN
# 417         158      9oMWun            62                GetMiddle   NaN
# 418         180      9oMWun           223       InsertionSort-Post   NaN
# 419         202      9oMWun            92               SquareRoot   NaN
#
#      Correctness  Difficulty  \
# 0           True           1
# 1           True           1
# 2           True           1
# 3           True           1
# 4           True           1
# ..           ...         ...
# 415        False           1
# 416         True           1
# 417         True           1
# 418         True           2
# 419         True           1
#
#                                              ClickData
# 0    98-60 105-106 356-103 98-64 322-101 146-138 38...
# 1    124-41 139-73 411-89 106-342 206-264 168-143 2...
# 2    147-56 129-139 209-55 221-150 206-195 211-238 ...
# 3    205-43 178-85 156-225 171-203 168-233 165-267 ...
# 4    194-61 451-54 199-91 155-255 155-328 156-371 8...
# ..                                                 ...
# 415  112-14 134-50 128-86 151-128 136-150 137-175 1...
# 416  96-8 154-48 144-68 185-93 200-145 166-164 136-...
# 417  99-11 136-43 140-77 153-112 153-154 152-170 14...
# 418  111-26 128-43 92-94 180-47 216-114 232-133 241...
# 419  152-28 171-71 194-88 196-118 196-130 192-173 2...
#
# [420 rows x 8 columns]

# %%
#unique_codes_if = df_if["Unique Code"].unique()
#unique_codes_for = df_for["Unique Code"].unique()
#unique_codes_while = df_while["Unique Code"].unique()
#unique_codes_do_while = df_do_while["Unique Code"].unique()
unique_codes_study = df_unique_codes["Unique Code"].dropna().unique()



df_vocabulary_if = pd.DataFrame()
df_vocabulary_for = pd.DataFrame()
df_vocabulary_while = pd.DataFrame()
df_vocabulary_do_while = pd.DataFrame()


for code in unique_codes_study:
    tmp_if = df_if.loc[df_if["Unique Code"]== code]
    tmp_for = df_for.loc[df_for["Unique Code"]== code]
    tmp_while = df_while.loc[df_while["Unique Code"]== code]
    tmp_do_while = df_do_while.loc[df_do_while["Unique Code"]== code]

    #tmp_post = df_post.loc[df_post["Unique Code"]==code]
    #df_result = df_result.append(tmp_pre)
    #df_result = df_result.append(tmp_post)
    df_vocabulary_if = df_vocabulary_for.append(tmp_if)
    df_vocabulary_for = df_vocabulary_for.append(tmp_for)
df_vocabulary_new.to_excel("results/behavioral/new_vocabulary.xlsx")

    path = r"C:\Users\fedel\Desktop\excelData\PhD_data.xlsx"
    writer = pd.ExcelWriter(path, engine='openpyxl')
    df3.to_excel(writer, 'x3', index=False)
    df4.to_excel(writer, 'x4', index=False)
    writer.save()
#list_unique_codes = []

#for code in unique_codes_if:
#    list_unique_codes.append(code)

#for code in unique_codes_for:
#    list_unique_codes.append(code)
    
#for code in unique_codes_while:
#    list_unique_codes.append(code)
    
#for code in unique_codes_do_while:
#    list_unique_codes.append(code)
    
#for code in list_unique_codes:
#    list_unique_codes.append(code)

#display(unique_codes_study)   

#counter=collections.Counter(list_unique_codes)
#counter.most_common()
# Out:
#     Unnamed: 0 Unique Code  Punkte  Max Punkte Fehler      Zeit Anmerkungen
# 15          39      3aUGho      21          23  18 23  00:09:32         NaN
#    Unnamed: 0 Unique Code  Punkte  Max Punkte       Fehler      Zeit  \
# 8          36      2aJAeo      19          23  14 18 20 23  00:10:40
#
#   Anmerkungen
# 8         NaN
#     Unnamed: 0 Unique Code  Punkte  Max Punkte Fehler      Zeit Anmerkungen
# 27          46      5hSLoa      23          23    NaN  00:09:48         NaN
#     Unnamed: 0 Unique Code  Punkte  Max Punkte Fehler      Zeit Anmerkungen
# 39          23      6vEHhi      22          23     10  00:15:24         NaN
# Empty DataFrame
# Columns: [Unnamed: 0, Unique Code, Punkte, Max Punkte, Fehler, Zeit, Anmerkungen]
# Index: []
#     Unnamed: 0 Unique Code  Punkte  Max Punkte Fehler      Zeit Anmerkungen
# 36          19      6armes      22          23     20  00:18:29         NaN
#    Unnamed: 0 Unique Code  Punkte  Max Punkte Fehler      Zeit Anmerkungen
# 4          35      1nCWte      21          23  10 14  00:15:43         NaN
#     Unnamed: 0 Unique Code  Punkte  Max Punkte Fehler      Zeit Anmerkungen
# 40          21      6vTGlo      21          23  14 19  00:23:29         NaN
#     Unnamed: 0 Unique Code  Punkte  Max Punkte Fehler      Zeit Anmerkungen
# 34           7      6aOGho      23          23    NaN  00:05:13         NaN
#     Unnamed: 0 Unique Code  Punkte  Max Punkte Fehler      Zeit Anmerkungen
# 48          24      9oMWun      22          23     23  00:10:17         NaN
#     Unnamed: 0 Unique Code  Punkte  Max Punkte Fehler      Zeit Anmerkungen
# 42          33      8aBMue      21          23  10 23  00:11:50         NaN
#     Unnamed: 0 Unique Code  Punkte  Max Punkte Fehler      Zeit Anmerkungen
# 16          27      3lRKia      21          23  18 20  00:36:12         NaN
#     Unnamed: 0 Unique Code  Punkte  Max Punkte    Fehler      Zeit Anmerkungen
# 46          22      9iKGhl      20          23  17 20 23  00:30:48         NaN
#     Unnamed: 0 Unique Code  Punkte  Max Punkte Fehler      Zeit Anmerkungen
# 45          17      9aBWha      21          23  14 23  00:15:46         NaN
#     Unnamed: 0 Unique Code  Punkte  Max Punkte    Fehler      Zeit Anmerkungen
# 11          40      2iEGül      20          23  14 17 18  00:17:31         NaN
#    Unnamed: 0 Unique Code  Punkte  Max Punkte    Fehler      Zeit Anmerkungen
# 5           3      1nTGsa      20          23  10 18 23  00:21:29         NaN
#     Unnamed: 0 Unique Code  Punkte  Max Punkte    Fehler      Zeit Anmerkungen
# 30          20      5nDFhi      20          23  17 18 23  00:09:20         NaN
#     Unnamed: 0 Unique Code  Punkte  Max Punkte Fehler      Zeit Anmerkungen
# 12          10      2nGAhe      22          23     10  00:12:56         NaN
#     Unnamed: 0 Unique Code  Punkte  Max Punkte    Fehler      Zeit Anmerkungen
# 31          47      5nFKho      20          23  10 14 23  00:12:15         NaN
#     Unnamed: 0 Unique Code  Punkte  Max Punkte Fehler      Zeit Anmerkungen
# 17           8      3rCHei      22          23     23  00:09:26         NaN
#     Unnamed: 0 Unique Code  Punkte  Max Punkte Fehler      Zeit Anmerkungen
# 32          25      5uHJei      22          23     23  00:11:24         NaN

# %%
mean_if = float(df_if["Punkte"].mean())
stddev_if = float(df_if["Punkte"].std())

mean_for = float(df_for["Punkte"].mean())
stddev_for = float(df_for["Punkte"].std())

mean_while = float(df_while["Punkte"].mean())
stddev_while = float(df_while["Punkte"].std())

mean_do_while = float(df_do_while["Punkte"].mean())
stddev_do_while = float(df_do_while["Punkte"].std())


print("if", mean_if, stddev_if)
print("for", mean_for, stddev_for)
print("while", mean_while, stddev_while)
print("do-while", mean_do_while, stddev_do_while)
# Out:
# if 21.0 1.8070158058105026
# for 23.64 2.5615683971077607
# while 23.959183673469386 3.4638561343866274
# do-while 23.877551020408163 1.1297612775350763

# %%
fehler_if = df_if["Fehler"].dropna()
fehler_for = df_for["Fehler"].dropna()
fehler_while = df_while["Fehler"].dropna()
fehler_do_while = df_do_while["Fehler"].dropna()

tasks_if = []
tasks_for = []
tasks_while = []
tasks_do_while = []

display(fehler_if)

for fehler in fehler_if:
    fehler = str(fehler)
    tmp = [int(n) for n in fehler.split()]
    for x in tmp:
        tasks_if.append(x)

for fehler in fehler_for:
    fehler = str(fehler)
    tmp = [int(n) for n in fehler.split()]
    for x in tmp:
        tasks_for.append(x)
        
for fehler in fehler_while:
    fehler = str(fehler)
    tmp = [int(n) for n in fehler.split()]
    for x in tmp:
        tasks_while.append(x)
        
for fehler in fehler_do_while:
    fehler = str(fehler)
    tmp = [int(n) for n in fehler.split()]
    for x in tmp:
        tasks_do_while.append(x)

counter_fehler_if=collections.Counter(tasks_if)
counter_fehler_for=collections.Counter(tasks_for)
counter_fehler_while=collections.Counter(tasks_while)
counter_fehler_do_while=collections.Counter(tasks_do_while)

counter_fehler_if.most_common()
counter_fehler_for.most_common()
counter_fehler_while.most_common()
counter_fehler_do_while.most_common()

print(counter_fehler_do_while)
tmp = dict(sorted(counter_fehler_do_while.items(), key=lambda item: item[1], reverse=True))
for k,v in tmp.items():
    print(k, v)
#tmp = collections.OrderedDict(sorted(counter_fehler_do_while.items()))
#for k, v in tmp.items():
#    print(k, v)
#print("For", counter_fehler_for)
#print("While", counter_fehler_while)
#print("Do-while", counter_fehler_do_while)
# Out:
# Counter({9: 24, 11: 6, 6: 4, 24: 3, 16: 3, 25: 3, 10: 2, 5: 2, 14: 2, 12: 1, 13: 1, 7: 1, 3: 1, 19: 1, 21: 1})
# 24 9
# 6 11
# 4 6
# 3 24
# 3 16
# 3 25
# 2 10
# 2 5
# 2 14
# 1 12
# 1 13
# 1 7
# 1 3
# 1 19
# 1 21
