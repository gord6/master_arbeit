# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
config_datasheet = r'./results/behavioral/compare/compare.xlsx'
config_datasheet_programming_pre = r'./results/Pretest_Programmieraufgaben - Kopie (2).xlsx'
config_datasheet_programming_post = r'./results/Posttest_Programmieraufgaben.xlsx'

# %%
raw_pre = pd.read_excel(config_datasheet_programming_pre)
raw_post = pd.read_excel(config_datasheet_programming_post)
raw = pd.read_excel(config_datasheet)

df = pd.DataFrame(raw)
df_pre = pd.DataFrame(raw_pre)
df_post = pd.DataFrame(raw_post)

# %%
from scipy.stats import mannwhitneyu


from pingouin import mwu
from pingouin import wilcoxon

pre_list_same = ["CommonChars-Pre", "ReverseArray-Pre", "BinarySearchStrings-Pre", "Multiples-Pre", "InsertionSort-Pre"]
post_list_same = ["CommonChars-Post", "ReverseArray-Post", "BinarySearchStrings-Post", "Multiples-Post", "InsertionSort-Post"]

pre_list_different = ["ContainsSubstring", "CountVowels", "CrossSum", "Swap", "GreatestCommonDivisor"]
post_list_different = ["IsPalindrome", "ReverseString", "Power", "GetMiddle", "SquareRoot"]

pre_list = pre_list_same + pre_list_different
post_list = post_list_same + post_list_different


df["Correctness"] = df["Correctness"].astype(int)

cliffs_delta_correctness_same = []
cliffs_delta_correctness_different = []
cliffs_delta_response_time_same = []
cliffs_delta_response_time_different = []



shapiro_pre_correctness_same = []
shapiro_pre_correctness_different = []
shapiro_pre_correctness = []

shapiro_pre_response_time_same = []
shapiro_pre_response_time_different = []
shapiro_pre_response_time = []

shapiro_post_correctness_same = []
shapiro_post_correctness_different = []
shapiro_post_correctness = []


shapiro_post_response_time_same = []
shapiro_post_response_time_different = []
shapiro_post_response_time = []

#ttest_correctness = []
#ttest_response_time = []
    
wilcoxon_response_time_same = []
wilcoxon_response_time_different = []
wilcoxon_correctness_same = []
wilcoxon_correctness_different = []

pre_response_time_mean_same = []
pre_response_time_mean_different = []
post_response_time_mean_same = []
post_response_time_mean_different = []

pre_correctness_mean_same = []
pre_correctness_mean_different = []
post_correctness_mean_same = []
post_correctness_mean_different = []

pre_difficulty_mean_same = []
pre_difficulty_mean_different = []
post_difficulty_mean_same = []
post_difficulty_mean_different = []

        
    #wilcoxon_correctness.append([post_list_same[i][:-5], tmp_pre_correctness.mean(), 
                                      #tmp_post_correctness.mean()])#, wilcoxon(tmp_pre_correctness, tmp_post_correctness)['p-val'][0]])
    #wilcoxon_response_time.append([post_list_same[i][:-5], tmp_pre_response_time.mean(), 
                                        #tmp_post_response_time.mean(), wilcoxon(tmp_pre_response_time, tmp_post_response_time)['p-val'][0]])

    #rint(stats.ttest_rel(tmp_pre_response_time, tmp_post_response_time))
    #print(mwu(tmp_pre_correctness, tmp_post_correctness))

import os 

#small, >= 0.11; medium, >= 0.28; large, >= 0.43

#shapiro <.05 - Ablehnung
#shapiro >.05 - Annahme - Normalverteilung

# %%
from cliffs_delta import cliffs_delta

response_time_same_list_pre = []
response_time_same_list_post = []

correctness_same_list_pre = []
correctness_same_list_post = []



for i in range(len(post_list_same)):
    tmp_pre_response_time = df[df["Algorithm"]==pre_list_same[i]]["ResponseTime"]
    tmp_pre_correctness = df[df["Algorithm"]==pre_list_same[i]]["Correctness"]
    tmp_pre_difficulty = df[df["Algorithm"]==pre_list_same[i]]["Difficulty"]
    
    tmp_post_response_time = df[df["Algorithm"]==post_list_same[i]]["ResponseTime"]
    tmp_post_correctness = df[df["Algorithm"]==post_list_same[i]]["Correctness"]
    tmp_post_difficulty = df[df["Algorithm"]==post_list_same[i]]["Difficulty"]
    
    
    response_time_list_pre = tmp_pre_response_time.tolist()
    response_time_list_post = tmp_post_response_time.tolist()
    
    correctness_list_pre = tmp_pre_correctness.tolist()
    correctness_list_post = tmp_post_correctness.tolist()
    
    print(response_time_list_pre)
    
    
    response_time_same_list_pre.extend(response_time_list_pre)
    response_time_same_list_post.extend(response_time_list_post)
    
    correctness_same_list_pre.extend(correctness_list_pre)
    correctness_same_list_post.extend(correctness_list_post)
    
    pre_response_time_mean_same.append(float(tmp_pre_response_time.mean()))
    post_response_time_mean_same.append(float(tmp_post_response_time.mean()))
    
    pre_correctness_mean_same.append(float(tmp_pre_correctness.mean()))
    post_correctness_mean_same.append(float(tmp_post_correctness.mean()))
    
    pre_difficulty_mean_same.append(tmp_pre_difficulty.mean())
    post_difficulty_mean_same.append(tmp_post_difficulty.mean())

    cliffs_delta_correctness_same.append([post_list_same[i][:-5], cliffs_delta(tmp_pre_correctness, tmp_post_correctness)[0]])
    cliffs_delta_response_time_same.append([post_list_same[i][:-5], cliffs_delta(tmp_pre_response_time, tmp_post_response_time)[0]])
    
    shapiro_pre_correctness_same.append([post_list_same[i][:-5], stats.shapiro(tmp_pre_correctness)])
    shapiro_post_correctness_same.append([post_list_same[i][:-5], stats.shapiro(tmp_post_correctness)])
    
    #print(tmp_pre_response_time)
    shapiro_pre_response_time_same.append([post_list_same[i][:-5], stats.shapiro(tmp_pre_response_time)])
    shapiro_post_response_time_same.append([post_list_same[i][:-5], stats.shapiro(tmp_post_response_time)])
    
    #ttest_correctness.append([post_list_same[i][:-5], stats.ttest_rel(tmp_pre_correctness, tmp_post_correctness)])
    #ttest_response_time.append([post_list_same[i][:-5], stats.ttest_rel(tmp_pre_response_time, tmp_post_response_time)])

    wilcoxon_correctness_same.append([post_list_same[i][:-5], wilcoxon(tmp_pre_correctness, tmp_post_correctness)])
    wilcoxon_response_time_same.append([post_list_same[i][:-5], wilcoxon(tmp_pre_response_time, tmp_post_response_time)])
# Out:
# [174, 161, 124, 212, 162, 132, 132, 99, 101, 78, 104, 86, 145, 86, 130, 166, 63, 102, 96, 70, 125]
# [106, 37, 102, 128, 54, 247, 154, 140, 257, 67, 40, 109, 188, 84, 84, 93, 73, 210, 111, 63, 198]
# [44, 146, 146, 156, 57, 120, 202, 256, 292, 122, 139, 41, 345, 137, 202, 661, 179, 144, 113, 239]
# [89, 67, 98, 132, 183, 161, 180, 159, 69, 69, 112, 167, 182, 66, 168, 85, 146, 92, 188, 101, 129]
# [75, 23, 64, 189, 42, 196, 217, 53, 188, 21, 72, 35, 190, 42, 543, 128, 56, 110, 102, 49, 105]
# C:\Users\Dominik\anaconda3\lib\site-packages\scipy\stats\morestats.py:2967: UserWarning: Exact p-value calculation does not work if there are ties. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# C:\Users\Dominik\anaconda3\lib\site-packages\scipy\stats\morestats.py:2981: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")
# ...

# %%
print(shapiro_pre_response_time_same)
# Out:
# [['CommonChars', ShapiroResult(statistic=0.9608932137489319, pvalue=0.5343010425567627)], ['ReverseArray', ShapiroResult(statistic=0.9190238118171692, pvalue=0.08296466618776321)], ['BinarySearchStrings', ShapiroResult(statistic=0.7698381543159485, pvalue=0.00031716987723484635)], ['Multiples', ShapiroResult(statistic=0.8991200923919678, pvalue=0.03364626318216324)], ['InsertionSort', ShapiroResult(statistic=0.7132011651992798, pvalue=4.039350460516289e-05)]]

# %% [markdown]
# ### Different Algorithms

# %%
from cliffs_delta import cliffs_delta


for i in range(len(post_list_same)):
    tmp_pre_response_time = df[df["Algorithm"]==pre_list_different[i]]["ResponseTime"]
    tmp_pre_correctness = df[df["Algorithm"]==pre_list_different[i]]["Correctness"]
    tmp_pre_difficulty = df[df["Algorithm"]==pre_list_different[i]]["Difficulty"]
    
    tmp_post_response_time = df[df["Algorithm"]==post_list_different[i]]["ResponseTime"]
    tmp_post_correctness = df[df["Algorithm"]==post_list_different[i]]["Correctness"]
    tmp_post_difficulty = df[df["Algorithm"]==post_list_different[i]]["Difficulty"]
    
    pre_response_time_mean_different.append(float(tmp_pre_response_time.mean()))
    post_response_time_mean_different.append(float(tmp_post_response_time.mean()))
    
    pre_correctness_mean_different.append(float(tmp_pre_correctness.mean()))
    post_correctness_mean_different.append(float(tmp_post_correctness.mean()))
    
    pre_difficulty_mean_different.append(tmp_pre_difficulty.mean())
    post_difficulty_mean_different.append(tmp_post_difficulty.mean())

    cliffs_delta_correctness_different.append([post_list_different[i], cliffs_delta(tmp_pre_correctness, tmp_post_correctness)[0]])
    cliffs_delta_response_time_different.append([post_list_different[i], cliffs_delta(tmp_pre_response_time, tmp_post_response_time)[0]])

    #shapiro_pre_correctness_same.append([post_list_same[i][:-5], stats.shapiro(tmp_pre_correctness)])
    #shapiro_post_correctness_same.append([post_list_same[i][:-5], stats.shapiro(tmp_post_correctness)])

    #shapiro_pre_response_time_same.append([post_list_same[i][:-5], stats.shapiro(tmp_pre_response_time)])
    #shapiro_post_response_time_same.append([post_list_same[i][:-5], stats.shapiro(tmp_post_response_time)])
    
    #ttest_correctness.append([post_list_same[i][:-5], stats.ttest_rel(tmp_pre_correctness, tmp_post_correctness)])
    #ttest_response_time.append([post_list_same[i][:-5], stats.ttest_rel(tmp_pre_response_time, tmp_post_response_time)])
    
    

    wilcoxon_correctness_different.append([post_list_different[i], wilcoxon(tmp_pre_correctness, tmp_post_correctness)])
    wilcoxon_response_time_different.append([post_list_different[i], wilcoxon(tmp_pre_response_time, tmp_post_response_time)])

# %%
print(sum(pre_difficulty_mean_different), sum(pre_difficulty_mean_same))
print(sum(pre_correctness_mean_different), sum(pre_correctness_mean_same))

print(sum(post_difficulty_mean_different), sum(post_difficulty_mean_same))
print(sum(post_correctness_mean_different), sum(post_correctness_mean_same))
# Out:
# 6.142857142857143 7.273809523809524
# 4.571428571428571 3.845238095238095
# 5.714285714285714 6.45
# 4.142857142857142 3.8904761904761904

# %%
df_statistic_correctness = pd.DataFrame(columns=['Programmieraufgaben', 'Korrektheit-Pre', 'Korrektheit-Post', 'Wilcoxon', 'Cliffs-Delta'])
df_statistic_response_time = pd.DataFrame(columns=['Programmieraufgaben', 'Antwortzeit-Pre', 'Antwortzeit-Post', 'Wilcoxon', 'Cliffs-Delta'])


df_response_time_same = pd.DataFrame([],
                                        columns=['Verständnisaufgabe', 'Beantwortungszeit-Pre', 'Beantwortungszeit-Post', 'Wilcoxon', 'Cliffs-Delta'])

df_correctness_same = pd.DataFrame([],
                                      columns=['Verständnisaufgabe', 'Korrektheit-Pre', 'Korrektheit-Post', 'Wilcoxon', 'Cliffs-Delta'])


print(len(wilcoxon_response_time_same))



response_time_same_pre = 0
response_time_same_post = 0

wilcoxon_response_time_same_pre = 0
wilcoxon_response_time_same_post = 0

cliffs_delta_response_time_same_pre = 0
cliffs_delta_response_time_same_post = 0

correctness_same_pre = 0
correctness_same_post = 0

wilcoxon_correctness_same_pre = 0
wilcoxon_correctness_same_post = 0

cliffs_delta_correctness_same_pre = 0
cliffs_delta_correctness_same_post = 0



for i in range(len(wilcoxon_response_time_same)):
    response_time_same_pre += pre_response_time_mean_same[i]
    response_time_same_post += post_response_time_mean_same[i]    
    
    correctness_same_pre += pre_correctness_mean_same[i]
    correctness_same_post += post_correctness_mean_same[i]
    
    

    
#print(response_time_same_pre_list)

response_time_same_pre /= len(wilcoxon_response_time_same)
response_time_same_post /= len(wilcoxon_response_time_same)

correctness_same_pre /= len(wilcoxon_response_time_same)
correctness_same_post /= len(wilcoxon_response_time_same)

#print(response_time_same_pre, response_time_same_post)
#print(correctness_same_pre, correctness_same_post)


print("Beantwortungszeit")
print("Cliff", cliffs_delta(response_time_same_list_pre, response_time_same_list_post))
print("Wilcoxon", wilcoxon(response_time_same_list_pre, response_time_same_list_post)["p-val"][0])


print("\n\nKorrektheit")
print("Cliff", cliffs_delta(correctness_same_list_pre, correctness_same_list_post))
print("Wilcoxon", wilcoxon(correctness_same_list_pre, correctness_same_list_post)["p-val"][0])


df_response_time_same = df_response_time_same.append({'Verständnisaufgabe': "V1-V5",
                                                      'Beantwortungszeit-Pre': int(round(response_time_same_pre)),
                                                      'Beantwortungszeit-Post': int(round(response_time_same_post)),
                                                      'Wilcoxon': round(wilcoxon(response_time_same_list_pre, response_time_same_list_post)["p-val"][0], 3),
                                                      'Cliffs-Delta': round(cliffs_delta(response_time_same_list_pre, response_time_same_list_post)[0], 2)
                                                     }, ignore_index=True)

correctness_same_pre *= 100
correctness_same_post *= 100

correctness_same_pre = round(correctness_same_pre, 2)




from researchpy import ttest



d = {'col1': response_time_same_list_pre, 'col2': response_time_same_list_post}

#print("MEDIAN", np.median(correctness_same_list_pre))
#print("MEDIAN", np.median(correctness_same_list_post))

print("MEDIAN", np.median(response_time_same_list_pre))
print("MEDIAN", np.median(response_time_same_list_post))
test_df = pd.DataFrame(data=d)

print()


tmp_tt = ttest(test_df["col1"], test_df["col2"], equal_variances=False, paired=True)
#tmp_tt = ttest(correctness_same_list_pre, correctness_same_list_post)

print("TTTT", tmp_tt) 
#print(wilcoxon(correctness_same_list_pre, correctness_same_list_post))


df_correctness_same = df_correctness_same.append({'Verständnisaufgabe': "V1-V5",
                                                      'Korrektheit-Pre': round(correctness_same_pre, 2),
                                                      'Korrektheit-Post': round(correctness_same_post, 2),
                                                      'Wilcoxon': round(wilcoxon(correctness_same_list_pre, correctness_same_list_post)["p-val"][0], 3),
                                                      'Cliffs-Delta': round(cliffs_delta(correctness_same_list_post, correctness_same_list_pre)[0], 2)
                                                     }, ignore_index=True)


display(df_response_time_same)

#for i in range(len(wilcoxon_response_time_same)):
#    df_response_time_same = df_response_time_same.append({'Verständnisaufgabe': "V" + str(i+1),
#                                                                            'Beantwortungszeit-Pre': int(round(pre_response_time_mean_same[i])),
#                                                                            'Beantwortungszeit-Post': int(round(post_response_time_mean_same[i])),
#                                                                            'Wilcoxon': round(wilcoxon_response_time_same[i][1]["p-val"][0], 5), 
#                                                                            'Cliffs-Delta': round(cliffs_delta_response_time_same[i][1], 5)}, ignore_index=True)
#    
#    pre_response_time_mean_same
#for i in range(len(wilcoxon_correctness_same)):
#    df_correctness_same = df_correctness_same.append({'Verständnisaufgabe': "V" + str(i+1),
#                                                                            'Korrektheit-Pre': round(pre_correctness_same_mean[i]*100, 2),
#                                                                            'Korrektheit-Post': round(post_correctness_same_mean[i]*100, 2),
#                                                                            'Wilcoxon': round(wilcoxon_correctness_same[i][1]["p-val"][0], 5), 
#                                                                            'Cliffs-Delta': round(cliffs_delta_correctness_same[i][1], 5)}, ignore_index=True)
#

with open(os.path.join(os.getcwd(),"response_time.tex"), "w"
) as tf:
    tf.write(df_response_time_same
             .to_latex(
             
             index=False,
             caption="Verständnisaufgaben: Beantwortungszeit",
                 escape=False,
                 column_format="ccccc",
             ))

    
    
with open(os.path.join(os.getcwd(),"correctness.tex"), "w"
) as tf:
    tf.write(df_correctness_same
             .to_latex(
             index=False,
             caption="Verständnisaufgaben: Korrektheit",
                 escape=False,
                 column_format="ccccc",
             ))
# Out:
# 5
# Beantwortungszeit
# Cliff (0.40791420118343197, 'medium')
# Wilcoxon 2.1117256704179314e-10
#
#
# Korrektheit
# Cliff (-0.009615384615384616, 'negligible')
# Wilcoxon 0.8484173099490682
# MEDIAN 121.0
# MEDIAN 77.0
#
# TTTT   Wilcoxon signed-rank test     results
# 0          Mean for col1 =   134.394231
# 1          Mean for col2 =    86.423077
# 2                W value =   746.500000
# 3                Z value =    -6.354500
# 4      Two sided p value =     0.000000
# 5                      r =    -0.440600
#   Verständnisaufgabe Beantwortungszeit-Pre Beantwortungszeit-Post  Wilcoxon  \
# 0              V1-V5                   135                     86       0.0
#
#    Cliffs-Delta
# 0          0.41

# %% [markdown]
# Programmieraufgaben

# %%
programming_tasks_pre = df_pre["Algorithmus"].unique()
programming_tasks_post = df_post["Algorithmus"].unique()

programming_tasks_pre_time = df_pre[df_pre["Algorithmus"]=="Kürzestes Wort"]["Zeit"]
programming_tasks_post_time = df_post[df_post["Algorithmus"]=="Maximales Produkt"]["Zeit"]

programming_tasks_pre_error_1 = df_pre[df_pre["Algorithmus"]=="Kürzestes Wort"]["Fehler"]
programming_tasks_pre_error_2 = df_pre[df_pre["Algorithmus"]=="Ungerade Anzahl"]["Fehler"]

programming_tasks_post_error_1 = df_post[df_post["Algorithmus"]=="Maximales Produkt"]["Fehler"]
programming_tasks_post_error_2 = df_post[df_post["Algorithmus"]=="String Wiederholung"]["Fehler"]

programming_tasks_pre_error = programming_tasks_pre_error_1.append(programming_tasks_pre_error_2)
programming_tasks_post_error = programming_tasks_post_error_1.append(programming_tasks_post_error_2)

#print(programming_tasks_time)
#shapiro <.05 - Ablehnung

wilcoxon_time = wilcoxon(programming_tasks_pre_time, programming_tasks_post_time)

wilcoxon_correctness_1 = wilcoxon(programming_tasks_pre_error_1, programming_tasks_post_error_2)
wilcoxon_correctness_2 = wilcoxon(programming_tasks_pre_error_2, programming_tasks_post_error_1)
wilcoxon_correctness_all = wilcoxon(programming_tasks_pre_error, programming_tasks_post_error)

cliffs_delta_time = cliffs_delta(programming_tasks_pre_time, programming_tasks_post_time)

cliffs_delta_correctness_1 = cliffs_delta(programming_tasks_pre_error_1, programming_tasks_post_error_2)
cliffs_delta_correctness_2 = cliffs_delta(programming_tasks_pre_error_2, programming_tasks_post_error_1)
cliffs_delta_correctness_all = cliffs_delta(programming_tasks_pre_error, programming_tasks_post_error)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Fehler'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-48715b49c3bb> in <module>
# ...

# %%
programming_tasks_correctness_df = pd.DataFrame([["P1/P4", round(programming_tasks_pre_error_1.mean(), 2),  round(programming_tasks_post_error_2.mean(),2),
                           round(wilcoxon_correctness_1["p-val"][0], 5), round(cliffs_delta_correctness_1, 5)],
                          ["P2/P3", round(programming_tasks_pre_error_2.mean(), 2),  round(programming_tasks_post_error_1.mean(), 2),
                           round(wilcoxon_correctness_2["p-val"][0], 5), round(cliffs_delta_correctness_2, 5)],
                          ["P1-P2/P3-P4", round(programming_tasks_pre_error.mean(), 2), round(programming_tasks_post_error.mean(), 2),
                           round(wilcoxon_correctness_all["p-val"][0], 5), round(cliffs_delta_correctness_all, 5)]],
                        columns=['Programmieraufgabe', 'Pretest', 'Posttest' , 'Wilcoxon', 'Cliffs-Delta'])



with open(
    os.path.join(os.getcwd(),"programming_tasks_correctness.tex"), "w"
) as tf:
    tf.write(programming_tasks_correctness_df
             .to_latex(
             index=False,
             caption="Programmieraufgaben: Korrrektheit",
                 label="tab:table_label",
                 escape=False,
                 column_format="cccccc",
             ))

# %%
import time

pre_time = time.strftime('%H:%M:%S', time.gmtime(programming_tasks_pre_time.mean()))
post_time = time.strftime('%H:%M:%S', time.gmtime(programming_tasks_post_time.mean()))


programming_tasks_time_df = pd.DataFrame([["P1-P2/P3-P4", pre_time, post_time,
                                         wilcoxon_time["p-val"][0], cliffs_delta_time]],
                                        columns=['Programmieraufgaben', 'Beantwortungszeit-Pre', 'Beantwortungszeit-Post', 'Wilcoxon', 'Cliffs-Delta'])



with open(
    os.path.join(os.getcwd(),"programming_tasks_time.tex"), "w"
) as tf:
    tf.write(programming_tasks_time_df
             .to_latex(
             index=False,
             caption="Programmieraufgaben: Beantwortungszeit",
                 escape=False,
                 column_format="cccccc",
             ))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-612393631807> in <module>
#       6
#       7 programming_tasks_time_df = pd.DataFrame([["P1-P2/P3-P4", pre_time, post_time,
# ----> 8                                          wilcoxon_time["p-val"][0], cliffs_delta_time]],
#       9                                         columns=['Programmieraufgaben', 'Beantwortungszeit-Pre', 'Beantwortungszeit-Post', 'Wilcoxon', 'Cliffs-Delta'])
#      10
#
# NameError: name 'wilcoxon_time' is not defined

# %%
from researchpy import ttest

print(pre_time)

d = {'col1': pre_time, 'col2': response_time_same_list_post}

#print("MEDIAN", np.median(correctness_same_list_pre))
#print("MEDIAN", np.median(correctness_same_list_post))

print("MEDIAN", np.median(response_time_same_list_pre))
print("MEDIAN", np.median(response_time_same_list_post))
test_df = pd.DataFrame(data=d)

print()


tmp_tt = ttest(test_df["col1"], test_df["col2"], equal_variances=False, paired=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-7623d77ec1f3> in <module>
#       1 from researchpy import ttest
#       2
# ----> 3 print(pre_time)
#       4
#       5 d = {'col1': pre_time, 'col2': response_time_same_list_post}
#
# NameError: name 'pre_time' is not defined

# %%
# perform mann whitney test
stat, p_value = mannwhitneyu(pre_common_chars_time, post_common_chars_time)
print('Statistics=%.2f, p=%f' % (stat, p_value))
# Level of significance
#alpha = 0.05
# conclusion
if p_value < alpha:
    print('Reject Null Hypothesis (Significant difference between two samples)')
else:
    print('Do not Reject Null Hypothesis (No significant difference between two samples)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-65b15633cf8b> in <module>
#       1 # perform mann whitney test
# ----> 2 stat, p_value = mannwhitneyu(pre_common_chars_time, post_common_chars_time)
#       3 print('Statistics=%.2f, p=%f' % (stat, p_value))
#       4 # Level of significance
#       5 #alpha = 0.05
#
# NameError: name 'pre_common_chars_time' is not defined
